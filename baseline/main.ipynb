# %%
import os
import random
import gc
import pandas as pd
import numpy as np
from dateutil.relativedelta import relativedelta
from tqdm.notebook import tqdm, trange
import torch
import torch.multiprocessing as mp
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler

from methods.model import *
from methods.logger import *
from methods.processing import *
from methods.train import *

# %% [markdown]
# # 读取数据

# %%
mp.set_start_method('spawn', force=True)
main_device_name = 0
print('Read Factor.')
factor = pd.read_pickle('/home/datamake117/data/haris/dataset/total_date.pkl')                      # 日期+股票代码
grouped = pd.read_pickle('/home/datamake117/data/haris/dataset/grouped_adj.pkl').fillna(0)          # 特征
grouped_label = pd.read_pickle('/home/datamake117/data/haris/dataset/grouped_label_adj.pkl')        # 标签
grouped_liquidity = pd.read_pickle('/home/datamake117/data/haris/dataset/grouped_liquidity.pkl')    # 流动性指标
grouped_liquidity.index = grouped_liquidity.index.strftime('%Y%m%d').astype(int)
correlation_df = pd.read_pickle('/home/datamake117/data/haris/dataset/corr_byday_abs.pkl')          # 因子筛选辅助数据
correlation_df.index = correlation_df.index.strftime('%Y%m%d').astype(int)
total_date_list = np.array(factor['date'].drop_duplicates().tolist())                               # 日期列表
# Out:
# Read Factor.

# %%
def main(
    round_num, dt1, dt2, dt3, dt4, dt5,
    correlation_df, grouped, grouped_label, grouped_liquidity,
    total_date_list, main_folder_name, 
    pid_num=5243, factor_num=2221, corr_thres=0.9, seed_num=5, model_mode=False, multi_model=6
    ):
    '''
    TODO: 参数含义
    para round_num: 轮数（周期序号）
    para dt1: 训练集开始时间
    para dt2: 验证集开始时间
    para dt3: 验证集结束时间
    para dt4: 测试集开始时间
    para dt5: 测试集结束时间
    
    dt1 ------训练集------ dt2 ------验证集------ dt3/dt4 ------测试集------ dt5
    
    para correlation_df: 因子筛选辅助数据
    para grouped: 按日期分组的因子数据
    para grouped_label: 按日期分组的标签数据
    para grouped_liquidity: 按日期分组的流动性数据
    para total_date_list: 全部日期
    para main_folder_name: 主文件夹名称
    para pid_num: 股票数量
    para factor_num: 因子数量
    para corr_thres: 因子筛选相关系数阈值
    para seed_num: 每个模型的种子数
    para model_mode: 是否继续训练
    para multi_model: 模型数量
    '''
    seed_list = []
    for i in range(seed_num):
        random.seed(i)
        seed_list.append(list(random.sample(range(100), multi_model)))
    total_train_num = len(seed_list)  # seed_num * multi_model
    total_test_output = []
    total_test_name = 'test_output_' + str(round_num) + '.pt'
    total_date_pid_name = 'test_date_pid_' + str(round_num) + '.pt'
    save_path = "/home/datamake117/data/haris/DL/" + main_folder_name
    
    # 根据给定的时间范围 dt1 到 dt3，选出训练集的日期列表。之后，有一个特别的日期范围处理（过滤掉指定日期段的训练数据）。
    date_list_train = total_date_list[np.where((total_date_list >= dt1) & (total_date_list < dt3))[0]]
    # 若20240223在训练周期或测试周期内，训练周期或测试周期去除20240201-20240223这一时间段
    if 20240223 >= dt1 and 20240223 <= dt3:
        date_list_train = np.array([date_train for date_train in date_list_train if date_train < 20240201 or date_train > 20240223])
    total_ts_train_val1 = np.zeros((len(date_list_train), pid_num, factor_num)) # 因子数据 shape: (len(date_list_train), pid_num, factor_num)
    total_label_train_val = np.zeros((len(date_list_train), pid_num, 5))        # 标签数据 shape: (len(date_list_train), pid_num, 5)
    total_group_train_val = np.zeros((len(date_list_train), pid_num, 1))        # 流动性数据 shape: (len(date_list_train), pid_num, 1)
    for i in trange(len(date_list_train), desc='train_val_data'):
        date = date_list_train[i]
        total_ts_train_val1[i, :, :] = grouped.loc[date].iloc[:pid_num, :]          # 因子
        total_label_train_val[i, :, :] = grouped_label.loc[date].iloc[:pid_num, :]  # 标签
        # 根据流动性调整收益率前7%-10%附近的训练标签：label(returns)
        total_label_train_val[i, :, 0] = adjust_daily_returns(total_label_train_val[i, :, 0], total_label_train_val[i, :, 4])
        total_group_train_val[i, :, :] = np.array(grouped_liquidity.loc[date])[:pid_num].reshape(-1, 1)  # 流动性
    
    # 类似地，date_list_test 被定义为测试集的日期范围，时间从 dt4 到 dt5。
    date_list_test = total_date_list[np.where((total_date_list >= dt4) & (total_date_list < dt5))[0]]
    total_ts_test1 = np.zeros((len(date_list_test), pid_num, factor_num))
    total_label_test = np.zeros((len(date_list_test), pid_num, 5))
    total_group_test = np.zeros((len(date_list_test), pid_num, 1))
    for i in trange(len(date_list_test), desc='test_data'):
        date = date_list_test[i]
        total_ts_test1[i, :, :] = grouped.loc[date].iloc[:pid_num, :]
        total_label_test[i, :, :] = grouped_label.loc[date].iloc[:pid_num, :]
        total_label_test[i, :, 0] = adjust_daily_returns(total_label_test[i, :, 0], total_label_test[i, :, 4])
        total_group_test[i, :, :] = np.array(grouped_liquidity.loc[date])[:pid_num].reshape(-1, 1)
    
    # 流动性数据归一化
    def min_max_standard(column):
        return (column - column.min()) / (column.max() - column.min())
    print('Min-max scaling.')
    total_group_train_val, total_group_test = min_max_standard(total_group_train_val), min_max_standard(total_group_test)
    
    # 因子数据标准化
    print('Standard scaling.')
    scaler = StandardScaler()
    total_ts_train_val1 = np.apply_along_axis(
        lambda x: np.clip(x, np.percentile(x, 0.5), np.percentile(x, 99.5)), axis=0, arr=total_ts_train_val1.reshape(-1, factor_num)
        )  # 去极值，保留5%-95%数据
    total_ts_train_val1 = total_ts_train_val1.reshape(len(date_list_train), pid_num, factor_num)
    total_ts_train_val1 = np.nan_to_num(scaler.fit_transform(total_ts_train_val1.reshape(-1, factor_num)).reshape(len(date_list_train), pid_num, factor_num), nan=0)
    total_ts_test1 = np.apply_along_axis(
        lambda x: np.clip(x, np.percentile(x, 0.5), np.percentile(x, 99.5)), axis=0, arr=total_ts_test1.reshape(-1, factor_num)
        )
    total_ts_test1 = total_ts_test1.reshape(len(date_list_test), pid_num, factor_num)
    total_ts_test1 = np.nan_to_num(scaler.transform(total_ts_test1.reshape(-1, factor_num)).reshape(len(date_list_test), pid_num, factor_num), nan=0)
    
    # KFold 交叉验证（并行训练）  TODO: 看到这里
    print('KFold training.')
    kf = KFold(n_splits=total_train_num, shuffle=False)
    processes = []
    for train_num, index_tuple in enumerate(kf.split(total_ts_train_val1)):
        p = mp.Process(
            target=train_one_Fold, 
            args=(
                round_num, train_num, index_tuple, main_folder_name,
                total_ts_train_val1, total_label_train_val, total_group_train_val, date_list_train,
                total_ts_test1, total_label_test, total_group_test, date_list_test,
                correlation_df, seed_list, dt1, dt2, dt3, dt4, dt5,
                factor_num, corr_thres, save_path, model_mode, multi_model
                )
            )
        processes.append(p)
        p.start()
    for p in processes:
        p.join()
    
    torch.cuda.empty_cache()
    gc.collect()
    
    # 保存测试数据
    print('Save test data.')
    total_test_output = []
    for train_num in range(total_train_num):
        test_name = 'test_output_ic' + str(round_num) + str(train_num) + '.pt'
        test_path = os.path.join(save_path, test_name)
        total_test_output.append(torch.load(test_path))
        
    total_test_path = os.path.join(save_path, total_test_name)
    total_date_pid_path = os.path.join(save_path, total_date_pid_name)
    
    total_test_output = torch.stack(total_test_output)
    weight_tensor = torch.tensor([0.1, 0.15, 0.2, 0.25, 0.3]).view(-1, *([1] * (total_test_output.dim() - 1)))
    total_test_output = (total_test_output * weight_tensor).sum(dim=0)
    torch.save(total_test_output, total_test_path)
    
    stocks = np.array(grouped_label.loc[20200102].index)
    repeated_stocks = np.tile(stocks, len(date_list_test))
    repeated_dates = np.repeat(date_list_test, len(stocks))
    date_pid_test = np.column_stack((repeated_dates, repeated_stocks))
    torch.save(date_pid_test, total_date_pid_path)
    
    del total_ts_train_val1
    del total_ts_test1
    del total_label_train_val
    del total_label_test
    del total_group_train_val
    del total_group_test
    
    torch.cuda.empty_cache()
    gc.collect()

# %% [markdown]
# # 训练和测试

# %%
folder_path = "/home/datamake117/data/haris/DL/" + main_folder_name
os.makedirs(folder_path, exist_ok=True)

# 第1轮
print('Round 1.')
round_num = 1
dt1 = int(pd.to_datetime("2020-07-01").strftime('%Y%m%d'))  # 训练集开始时间
dt2 = int(pd.to_datetime("2022-07-01").strftime('%Y%m%d'))  # 验证集开始时间
dt3 = int(pd.to_datetime("2022-12-30").strftime('%Y%m%d'))  # 验证集结束时间
dt4 = int(pd.to_datetime("2023-01-01").strftime('%Y%m%d'))  # 测试集开始时间
dt5 = int(pd.to_datetime("2023-07-01").strftime('%Y%m%d'))  # 测试集结束时间
main(
    round_num, dt1, dt2, dt3, dt4, dt5,
    correlation_df, grouped, grouped_label, grouped_liquidity,
    total_date_list, main_folder_name, corr_thres=0.9
    )
torch.cuda.empty_cache()
gc.collect()

test_output1 = torch.load("/home/datamake117/data/haris/DL/" + main_folder_name + "/test_output_1.pt")
test_output = torch.cat([test_output1])
test_output = test_output.cpu()
date_pid1 = torch.load("/home/datamake117/data/haris/DL/" + main_folder_name + "/test_date_pid_1.pt")
total_date_pid = np.concatenate([date_pid1], axis=0)
total_date_pid_test = total_date_pid
grading_factor = pd.DataFrame(index=np.unique(total_date_pid_test[:, 0]), columns=np.unique(total_date_pid_test[:, 1]))
test_output_list = test_output.tolist()
for i in range(len(total_date_pid_test)):
    grading_factor.loc[total_date_pid_test[i][0], total_date_pid_test[i][1]] = test_output_list[i]
grading_factor.to_pickle("/home/datamake117/data/haris/DL/" + main_folder_name + "/单次_KFold_2023.pkl")

gc.collect()
# Out:
# Round 1.
# train_val_data:   0%|          | 0/610 [00:00<?, ?it/s]
# test_data:   0%|          | 0/118 [00:00<?, ?it/s]
# Min-max scaling.
# Standard scaling.
# /home/datamake117/.local/lib/python3.9/site-packages/numpy/lib/function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/utils/extmath.py:1051: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/utils/extmath.py:1056: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/utils/extmath.py:1076: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# /home/datamake117/.local/lib/python3.9/site-packages/numpy/lib/function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# KFold training.
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2025/02/18 16:04:41 train.py INFO Period1, Train0, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230701
# 2025/02/18 16:04:41 train.py INFO Train1 Shape: torch.Size([488, 5243, 2221]), Val1 Shape: torch.Size([121, 5243, 2221]), Test1 Shape: torch.Size([118, 5243, 2221])
# 2025/02/18 16:04:41 train.py INFO Start Training
# 2025/02/18 16:06:26 train.py INFO Epoch[1/200], Time:105.25sec, Train Loss: 0.912891, Val Loss: 0.8854135870933533,0.8999522924423218,0.8867323994636536,0.8855928182601929,0.8941771388053894,0.889863908290863
# 2025/02/18 16:06:26 model.py INFO Validation loss decreased (inf --> 0.885414).  Saving model 0.0...
# 2025/02/18 16:06:26 model.py INFO Validation loss decreased (inf --> 0.899952).  Saving model 1.0...
# 2025/02/18 16:06:26 model.py INFO Validation loss decreased (inf --> 0.886732).  Saving model 2.0...
# 2025/02/18 16:06:26 model.py INFO Validation loss decreased (inf --> 0.885593).  Saving model 3.0...
# 2025/02/18 16:06:26 model.py INFO Validation loss decreased (inf --> 0.894177).  Saving model 4.0...
# 2025/02/18 16:06:26 model.py INFO Validation loss decreased (inf --> 0.889864).  Saving model 5.0...
# 2025/02/18 16:08:09 train.py INFO Epoch[2/200], Time:102.16sec, Train Loss: 0.878617, Val Loss: 0.8763024806976318,0.8903874158859253,0.8803919553756714,0.8725102543830872,0.8837936520576477,0.882169246673584
# 2025/02/18 16:08:09 model.py INFO Validation loss decreased (0.885414 --> 0.876302).  Saving model 0.0...
# 2025/02/18 16:08:09 model.py INFO Validation loss decreased (0.899952 --> 0.890387).  Saving model 1.0...
# 2025/02/18 16:08:09 model.py INFO Validation loss decreased (0.886732 --> 0.880392).  Saving model 2.0...
# 2025/02/18 16:08:09 model.py INFO Validation loss decreased (0.885593 --> 0.872510).  Saving model 3.0...
# 2025/02/18 16:08:09 model.py INFO Validation loss decreased (0.894177 --> 0.883794).  Saving model 4.0...
# 2025/02/18 16:08:09 model.py INFO Validation loss decreased (0.889864 --> 0.882169).  Saving model 5.0...
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2025/02/18 16:08:48 train.py INFO Period1, Train1, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230701
# 2025/02/18 16:08:48 train.py INFO Train1 Shape: torch.Size([488, 5243, 2221]), Val1 Shape: torch.Size([121, 5243, 2221]), Test1 Shape: torch.Size([118, 5243, 2221])
# 2025/02/18 16:08:48 train.py INFO Start Training
# 2025/02/18 16:10:16 train.py INFO Epoch[3/200], Time:127.30sec, Train Loss: 0.865701, Val Loss: 0.8707796931266785,0.8792271614074707,0.8758072257041931,0.8677513599395752,0.8796634078025818,0.8804073929786682
# 2025/02/18 16:10:16 model.py INFO Validation loss decreased (0.876302 --> 0.870780).  Saving model 0.0...
# 2025/02/18 16:10:16 model.py INFO Validation loss decreased (0.890387 --> 0.879227).  Saving model 1.0...
# 2025/02/18 16:10:16 model.py INFO Validation loss decreased (0.880392 --> 0.875807).  Saving model 2.0...
# 2025/02/18 16:10:16 model.py INFO Validation loss decreased (0.872510 --> 0.867751).  Saving model 3.0...
# 2025/02/18 16:10:16 model.py INFO Validation loss decreased (0.883794 --> 0.879663).  Saving model 4.0...
# 2025/02/18 16:10:16 model.py INFO Validation loss decreased (0.882169 --> 0.880407).  Saving model 5.0...
# 2025/02/18 16:10:49 train.py INFO Epoch[1/200], Time:121.14sec, Train Loss: 0.910123, Val Loss: 0.876903235912323,0.8782098293304443,0.887276291847229,0.8767205476760864,0.8845949769020081,0.888168215751648
# 2025/02/18 16:10:49 model.py INFO Validation loss decreased (inf --> 0.876903).  Saving model 0.0...
# 2025/02/18 16:10:49 model.py INFO Validation loss decreased (inf --> 0.878210).  Saving model 1.0...
# 2025/02/18 16:10:49 model.py INFO Validation loss decreased (inf --> 0.887276).  Saving model 2.0...
# 2025/02/18 16:10:49 model.py INFO Validation loss decreased (inf --> 0.876721).  Saving model 3.0...
# 2025/02/18 16:10:49 model.py INFO Validation loss decreased (inf --> 0.884595).  Saving model 4.0...
# 2025/02/18 16:10:49 model.py INFO Validation loss decreased (inf --> 0.888168).  Saving model 5.0...
# 2025/02/18 16:12:15 train.py INFO Epoch[4/200], Time:119.08sec, Train Loss: 0.856850, Val Loss: 0.8727447986602783,0.880577802658081,0.8734951019287109,0.8671039342880249,0.8754411935806274,0.8782275915145874
# 2025/02/18 16:12:15 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:12:15 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:12:15 model.py INFO Validation loss decreased (0.875807 --> 0.873495).  Saving model 2.0...
# 2025/02/18 16:12:15 model.py INFO Validation loss decreased (0.867751 --> 0.867104).  Saving model 3.0...
# 2025/02/18 16:12:15 model.py INFO Validation loss decreased (0.879663 --> 0.875441).  Saving model 4.0...
# 2025/02/18 16:12:15 model.py INFO Validation loss decreased (0.880407 --> 0.878228).  Saving model 5.0...
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2025/02/18 16:13:03 train.py INFO Epoch[2/200], Time:134.11sec, Train Loss: 0.875405, Val Loss: 0.8693834543228149,0.8783172369003296,0.8823095560073853,0.8693885207176208,0.8818444013595581,0.8803638219833374
# 2025/02/18 16:13:03 model.py INFO Validation loss decreased (0.876903 --> 0.869383).  Saving model 0.0...
# 2025/02/18 16:13:03 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:13:03 model.py INFO Validation loss decreased (0.887276 --> 0.882310).  Saving model 2.0...
# 2025/02/18 16:13:03 model.py INFO Validation loss decreased (0.876721 --> 0.869389).  Saving model 3.0...
# 2025/02/18 16:13:03 model.py INFO Validation loss decreased (0.884595 --> 0.881844).  Saving model 4.0...
# 2025/02/18 16:13:03 model.py INFO Validation loss decreased (0.888168 --> 0.880364).  Saving model 5.0...
# 2025/02/18 16:13:08 train.py INFO Period1, Train2, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230701
# 2025/02/18 16:13:08 train.py INFO Train1 Shape: torch.Size([488, 5243, 2221]), Val1 Shape: torch.Size([121, 5243, 2221]), Test1 Shape: torch.Size([118, 5243, 2221])
# 2025/02/18 16:13:08 train.py INFO Start Training
# 2025/02/18 16:14:42 train.py INFO Epoch[5/200], Time:146.33sec, Train Loss: 0.849061, Val Loss: 0.8712359666824341,0.8780060410499573,0.8718007206916809,0.8652117848396301,0.876368522644043,0.8715007305145264
# 2025/02/18 16:14:42 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 16:14:42 model.py INFO Validation loss decreased (0.879227 --> 0.878006).  Saving model 1.0...
# 2025/02/18 16:14:42 model.py INFO Validation loss decreased (0.873495 --> 0.871801).  Saving model 2.0...
# 2025/02/18 16:14:42 model.py INFO Validation loss decreased (0.867104 --> 0.865212).  Saving model 3.0...
# 2025/02/18 16:14:42 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:14:42 model.py INFO Validation loss decreased (0.878228 --> 0.871501).  Saving model 5.0...
# 2025/02/18 16:15:17 train.py INFO Epoch[3/200], Time:134.24sec, Train Loss: 0.862572, Val Loss: 0.8670958280563354,0.8823834657669067,0.87401282787323,0.866783618927002,0.8820359110832214,0.8736271262168884
# 2025/02/18 16:15:17 model.py INFO Validation loss decreased (0.869383 --> 0.867096).  Saving model 0.0...
# 2025/02/18 16:15:17 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 16:15:17 model.py INFO Validation loss decreased (0.882310 --> 0.874013).  Saving model 2.0...
# 2025/02/18 16:15:17 model.py INFO Validation loss decreased (0.869389 --> 0.866784).  Saving model 3.0...
# 2025/02/18 16:15:17 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:15:17 model.py INFO Validation loss decreased (0.880364 --> 0.873627).  Saving model 5.0...
# 2025/02/18 16:15:25 train.py INFO Epoch[1/200], Time:136.86sec, Train Loss: 0.907571, Val Loss: 0.8934702277183533,0.8937758207321167,0.9119254946708679,0.8919533491134644,0.8956466317176819,0.9140941500663757
# 2025/02/18 16:15:25 model.py INFO Validation loss decreased (inf --> 0.893470).  Saving model 0.0...
# 2025/02/18 16:15:25 model.py INFO Validation loss decreased (inf --> 0.893776).  Saving model 1.0...
# 2025/02/18 16:15:25 model.py INFO Validation loss decreased (inf --> 0.911925).  Saving model 2.0...
# 2025/02/18 16:15:25 model.py INFO Validation loss decreased (inf --> 0.891953).  Saving model 3.0...
# 2025/02/18 16:15:25 model.py INFO Validation loss decreased (inf --> 0.895647).  Saving model 4.0...
# 2025/02/18 16:15:25 model.py INFO Validation loss decreased (inf --> 0.914094).  Saving model 5.0...
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2025/02/18 16:16:57 train.py INFO Period1, Train3, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230701
# 2025/02/18 16:16:57 train.py INFO Train1 Shape: torch.Size([488, 5243, 2221]), Val1 Shape: torch.Size([121, 5243, 2221]), Test1 Shape: torch.Size([118, 5243, 2221])
# 2025/02/18 16:16:57 train.py INFO Start Training
# 2025/02/18 16:17:07 train.py INFO Epoch[6/200], Time:145.02sec, Train Loss: 0.841188, Val Loss: 0.8735456466674805,0.8755655288696289,0.8677828311920166,0.8802815675735474,0.8745405673980713,0.8742602467536926
# 2025/02/18 16:17:07 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 16:17:07 model.py INFO Validation loss decreased (0.878006 --> 0.875566).  Saving model 1.0...
# 2025/02/18 16:17:07 model.py INFO Validation loss decreased (0.871801 --> 0.867783).  Saving model 2.0...
# 2025/02/18 16:17:07 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:17:07 model.py INFO Validation loss decreased (0.875441 --> 0.874541).  Saving model 4.0...
# 2025/02/18 16:17:07 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:17:45 train.py INFO Epoch[4/200], Time:147.46sec, Train Loss: 0.853292, Val Loss: 0.8679538369178772,0.8912560939788818,0.8694184422492981,0.8630713224411011,0.8900303840637207,0.8736089468002319
# 2025/02/18 16:17:45 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:17:45 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 16:17:45 model.py INFO Validation loss decreased (0.874013 --> 0.869418).  Saving model 2.0...
# 2025/02/18 16:17:45 model.py INFO Validation loss decreased (0.866784 --> 0.863071).  Saving model 3.0...
# 2025/02/18 16:17:45 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 16:17:45 model.py INFO Validation loss decreased (0.873627 --> 0.873609).  Saving model 5.0...
# 2025/02/18 16:17:59 train.py INFO Epoch[2/200], Time:154.04sec, Train Loss: 0.872525, Val Loss: 0.8864887952804565,0.8869646787643433,0.902567446231842,0.8856154680252075,0.8869132399559021,0.9037550687789917
# 2025/02/18 16:17:59 model.py INFO Validation loss decreased (0.893470 --> 0.886489).  Saving model 0.0...
# 2025/02/18 16:17:59 model.py INFO Validation loss decreased (0.893776 --> 0.886965).  Saving model 1.0...
# 2025/02/18 16:17:59 model.py INFO Validation loss decreased (0.911925 --> 0.902567).  Saving model 2.0...
# 2025/02/18 16:17:59 model.py INFO Validation loss decreased (0.891953 --> 0.885615).  Saving model 3.0...
# 2025/02/18 16:17:59 model.py INFO Validation loss decreased (0.895647 --> 0.886913).  Saving model 4.0...
# 2025/02/18 16:17:59 model.py INFO Validation loss decreased (0.914094 --> 0.903755).  Saving model 5.0...
# 2025/02/18 16:19:24 train.py INFO Epoch[1/200], Time:147.30sec, Train Loss: 0.910175, Val Loss: 0.879683256149292,0.8937294483184814,0.8958180546760559,0.882215142250061,0.8925836086273193,0.8983974456787109
# 2025/02/18 16:19:24 model.py INFO Validation loss decreased (inf --> 0.879683).  Saving model 0.0...
# 2025/02/18 16:19:24 model.py INFO Validation loss decreased (inf --> 0.893729).  Saving model 1.0...
# 2025/02/18 16:19:24 model.py INFO Validation loss decreased (inf --> 0.895818).  Saving model 2.0...
# 2025/02/18 16:19:24 model.py INFO Validation loss decreased (inf --> 0.882215).  Saving model 3.0...
# 2025/02/18 16:19:24 model.py INFO Validation loss decreased (inf --> 0.892584).  Saving model 4.0...
# 2025/02/18 16:19:24 model.py INFO Validation loss decreased (inf --> 0.898397).  Saving model 5.0...
# 2025/02/18 16:19:36 train.py INFO Epoch[7/200], Time:149.25sec, Train Loss: 0.832357, Val Loss: 0.8764196038246155,0.873254120349884,0.8694936037063599,0.8841841220855713,0.8731797933578491,0.8728165626525879
# 2025/02/18 16:19:36 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/02/18 16:19:36 model.py INFO Validation loss decreased (0.875566 --> 0.873254).  Saving model 1.0...
# 2025/02/18 16:19:36 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:19:36 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 16:19:36 model.py INFO Validation loss decreased (0.874541 --> 0.873180).  Saving model 4.0...
# 2025/02/18 16:19:36 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 16:20:12 train.py INFO Epoch[5/200], Time:146.65sec, Train Loss: 0.844921, Val Loss: 0.8668591976165771,0.8943460583686829,0.867892861366272,0.8681305050849915,0.8978824615478516,0.8713164925575256
# 2025/02/18 16:20:12 model.py INFO Validation loss decreased (0.867096 --> 0.866859).  Saving model 0.0...
# 2025/02/18 16:20:12 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/02/18 16:20:12 model.py INFO Validation loss decreased (0.869418 --> 0.867893).  Saving model 2.0...
# 2025/02/18 16:20:12 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:20:12 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 16:20:12 model.py INFO Validation loss decreased (0.873609 --> 0.871316).  Saving model 5.0...
# 2025/02/18 16:20:28 train.py INFO Epoch[3/200], Time:148.84sec, Train Loss: 0.859204, Val Loss: 0.8832072019577026,0.88309246301651,0.8983727693557739,0.8855986595153809,0.8835018873214722,0.9031161665916443
# 2025/02/18 16:20:28 model.py INFO Validation loss decreased (0.886489 --> 0.883207).  Saving model 0.0...
# 2025/02/18 16:20:28 model.py INFO Validation loss decreased (0.886965 --> 0.883092).  Saving model 1.0...
# 2025/02/18 16:20:28 model.py INFO Validation loss decreased (0.902567 --> 0.898373).  Saving model 2.0...
# 2025/02/18 16:20:28 model.py INFO Validation loss decreased (0.885615 --> 0.885599).  Saving model 3.0...
# 2025/02/18 16:20:28 model.py INFO Validation loss decreased (0.886913 --> 0.883502).  Saving model 4.0...
# 2025/02/18 16:20:28 model.py INFO Validation loss decreased (0.903755 --> 0.903116).  Saving model 5.0...
# 2025/02/18 16:21:49 train.py INFO Epoch[2/200], Time:144.97sec, Train Loss: 0.874700, Val Loss: 0.8752267956733704,0.8854943513870239,0.9007724523544312,0.8724268078804016,0.8898709416389465,0.9061282873153687
# 2025/02/18 16:21:49 model.py INFO Validation loss decreased (0.879683 --> 0.875227).  Saving model 0.0...
# 2025/02/18 16:21:49 model.py INFO Validation loss decreased (0.893729 --> 0.885494).  Saving model 1.0...
# 2025/02/18 16:21:49 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:21:49 model.py INFO Validation loss decreased (0.882215 --> 0.872427).  Saving model 3.0...
# 2025/02/18 16:21:49 model.py INFO Validation loss decreased (0.892584 --> 0.889871).  Saving model 4.0...
# 2025/02/18 16:21:49 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:22:07 train.py INFO Epoch[8/200], Time:150.85sec, Train Loss: 0.822210, Val Loss: 0.8851748704910278,0.8698079586029053,0.8720600605010986,0.8863310217857361,0.8694014549255371,0.8790250420570374
# 2025/02/18 16:22:07 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/02/18 16:22:07 model.py INFO Validation loss decreased (0.873254 --> 0.869808).  Saving model 1.0...
# 2025/02/18 16:22:07 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 16:22:07 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 16:22:07 model.py INFO Validation loss decreased (0.873180 --> 0.869401).  Saving model 4.0...
# 2025/02/18 16:22:07 model.py INFO EarlyStopping counter: 3 out of 10
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2025/02/18 16:22:57 train.py INFO Epoch[6/200], Time:165.18sec, Train Loss: 0.836090, Val Loss: 0.8667171597480774,0.8981723785400391,0.8675464391708374,0.865005612373352,0.8975235819816589,0.8682445287704468
# 2025/02/18 16:22:57 model.py INFO Validation loss decreased (0.866859 --> 0.866717).  Saving model 0.0...
# 2025/02/18 16:22:57 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/02/18 16:22:57 model.py INFO Validation loss decreased (0.867893 --> 0.867546).  Saving model 2.0...
# 2025/02/18 16:22:57 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 16:22:57 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/02/18 16:22:57 model.py INFO Validation loss decreased (0.871316 --> 0.868245).  Saving model 5.0...
# 2025/02/18 16:23:10 train.py INFO Period1, Train4, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230701
# 2025/02/18 16:23:10 train.py INFO Train1 Shape: torch.Size([488, 5243, 2221]), Val1 Shape: torch.Size([121, 5243, 2221]), Test1 Shape: torch.Size([118, 5243, 2221])
# 2025/02/18 16:23:10 train.py INFO Start Training
# 2025/02/18 16:23:14 train.py INFO Epoch[4/200], Time:165.53sec, Train Loss: 0.849592, Val Loss: 0.884900689125061,0.8824020624160767,0.9018720984458923,0.8874260187149048,0.8843263387680054,0.90525221824646
# 2025/02/18 16:23:14 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:23:14 model.py INFO Validation loss decreased (0.883092 --> 0.882402).  Saving model 1.0...
# 2025/02/18 16:23:14 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:23:14 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:23:14 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:23:14 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 16:24:40 train.py INFO Epoch[3/200], Time:170.84sec, Train Loss: 0.861712, Val Loss: 0.8720317482948303,0.8788929581642151,0.9023219347000122,0.8722196817398071,0.8842131495475769,0.9122728109359741
# 2025/02/18 16:24:40 model.py INFO Validation loss decreased (0.875227 --> 0.872032).  Saving model 0.0...
# 2025/02/18 16:24:40 model.py INFO Validation loss decreased (0.885494 --> 0.878893).  Saving model 1.0...
# 2025/02/18 16:24:40 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 16:24:40 model.py INFO Validation loss decreased (0.872427 --> 0.872220).  Saving model 3.0...
# 2025/02/18 16:24:40 model.py INFO Validation loss decreased (0.889871 --> 0.884213).  Saving model 4.0...
# 2025/02/18 16:24:40 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 16
24 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/02/18 16:57:30 train.py INFO Epoch[14/200], Time:65.62sec, Train Loss: 0.779181, Val Loss: 0.911864697933197,0.897855281829834,0.9103732705116272,0.9220784306526184,0.8850590586662292,0.9421036243438721
# 2025/02/18 16:57:30 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/02/18 16:57:30 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/02/18 16:57:30 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/02/18 16:57:30 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/02/18 16:57:30 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/02/18 16:57:30 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/02/18 16:58:36 train.py INFO Epoch[15/200], Time:66.39sec, Train Loss: 0.768138, Val Loss: 0.9242566227912903,0.9128702878952026,0.9103732705116272,0.9174773693084717,0.8879646062850952,0.9421036243438721
# 2025/02/18 16:58:36 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/02/18 16:58:36 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/02/18 16:58:36 model.py INFO EarlyStopping counter: 13 out of 10
# 2025/02/18 16:58:36 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/02/18 16:58:36 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/02/18 16:58:36 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/02/18 16:59:42 train.py INFO Epoch[16/200], Time:66.38sec, Train Loss: 0.758918, Val Loss: 0.927459716796875,0.8996639847755432,0.9103732705116272,0.9209507703781128,0.8970893025398254,0.9421036243438721
# 2025/02/18 16:59:42 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/02/18 16:59:42 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/02/18 16:59:42 model.py INFO EarlyStopping counter: 14 out of 10
# 2025/02/18 16:59:42 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/02/18 16:59:42 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/02/18 16:59:42 model.py INFO EarlyStopping counter: 13 out of 10
# 2025/02/18 17:00:25 train.py INFO Epoch[17/200], Time:42.74sec, Train Loss: 0.816055, Val Loss: 0.927459716796875,0.9124205112457275,0.9103732705116272,0.9209507703781128,0.9027793407440186,0.9421036243438721
# 2025/02/18 17:00:25 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/02/18 17:00:25 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/02/18 17:00:25 model.py INFO EarlyStopping counter: 15 out of 10
# 2025/02/18 17:00:25 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/02/18 17:00:25 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/02/18 17:00:25 model.py INFO EarlyStopping counter: 14 out of 10
# 2025/02/18 17:00:54 train.py INFO Epoch[18/200], Time:28.54sec, Train Loss: 0.846727, Val Loss: 0.927459716796875,0.9124205112457275,0.9103732705116272,0.9209507703781128,0.9084523916244507,0.9421036243438721
# 2025/02/18 17:00:54 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/02/18 17:00:54 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/02/18 17:00:54 model.py INFO EarlyStopping counter: 16 out of 10
# 2025/02/18 17:00:54 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/02/18 17:00:54 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/02/18 17:00:54 model.py INFO EarlyStopping counter: 15 out of 10
# 2025/02/18 17:00:54 train.py INFO Early stopping
# 2025/02/18 17:00:54 train.py INFO Val Loss: 0.8751987218856812,0.8706319332122803,0.8913982510566711,0.8767832517623901,0.8720861673355103,0.8961443305015564
# 2025/02/18 17:01:01 train.py INFO Test Loss: 0.015604
# 2025/02/18 17:01:05 train.py INFO Finish 4 Fold.
# Save test data.
# /tmp/ipykernel_3716635/1476732172.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   total_test_output.append(torch.load(test_path))
# /tmp/ipykernel_3716635/3943263448.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_output1 = torch.load("/home/datamake117/data/haris/DL/" + main_folder_name + "/test_output_1.pt")
# /tmp/ipykernel_3716635/3943263448.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   date_pid1 = torch.load("/home/datamake117/data/haris/DL/" + main_folder_name + "/test_date_pid_1.pt")
# 0

# %%
# 第2-8轮
total_date_list = np.array(factor['date'].drop_duplicates().tolist())
rolling_step = 3    # 3个月滚动训练
window_size = 24    # 训练集大小
val_size = 3        # 验证集大小
corr_thres = 0.9
for round_num in range(2, 9):
    print('Round %i.' % round_num)
    start_date = pd.to_datetime('2021-01-01')
    dt1 = start_date + relativedelta(months=rolling_step * (round_num - 2)) # 训练集开始时间
    dt2 = dt1 + relativedelta(months=window_size)                           # 验证集开始时间
    dt3 = dt2 + relativedelta(months=val_size)                              # 验证集结束时间
    dt4 = dt3                                                               # 测试集开始时间
    dt5 = dt3 + relativedelta(months=rolling_step)                          # 测试集结束时间
    dt3 = total_date_list[total_date_list < int(dt3.strftime('%Y%m%d'))][-1]
    dt1, dt2, dt3, dt4, dt5 = int(dt1.strftime('%Y%m%d')), int(dt2.strftime('%Y%m%d')), int(dt3), int(dt4.strftime('%Y%m%d')), int(dt5.strftime('%Y%m%d'))
    main(
        round_num, dt1, dt2, dt3, dt4, dt5,
        correlation_df, grouped, grouped_label, grouped_liquidity,
        total_date_list, main_folder_name, corr_thres=0.9, seed_num=5, model_mode=False
        )
    torch.cuda.empty_cache()
    gc.collect()

test_output_list = []
for round_num in range(2, 9):
    test_output = torch.load("/home/datamake117/data/haris/DL/" + main_folder_name + "/test_output_" + str(round_num) + ".pt")
    test_output_list.append(test_output)
test_output = torch.cat(test_output_list)
test_output = test_output.cpu()
date_pid_list = []
for round_num in range(2, 9):
    date_pid = torch.load("/home/datamake117/data/haris/DL/" + main_folder_name + "/test_date_pid_" + str(round_num) + ".pt")
    date_pid_list.append(date_pid)
total_date_pid = np.concatenate(date_pid_list, axis=0)
total_date_pid_test = total_date_pid
grading_factor = pd.DataFrame(index=np.unique(total_date_pid_test[:, 0]), columns=np.unique(total_date_pid_test[:, 1]))
test_output_list = test_output.tolist()
for i in range(len(total_date_pid_test)):
    grading_factor.loc[total_date_pid_test[i][0], total_date_pid_test[i][1]] = test_output_list[i]
grading_factor2023 = pd.read_pickle("/home/datamake117/data/haris/DL/" + main_folder_name + "/单次_KFold_2023.pkl")
grading_factor2023 = grading_factor2023[grading_factor2023.index < 20230401]
grading_factor = pd.concat([grading_factor2023, grading_factor], axis=0)
grading_factor.to_feather("/home/datamake117/data/haris/DL/" + main_folder_name + "/单次_KFold_0.fea")
# Out:
# Round 2.
# train_val_data:   0%|          | 0/543 [00:00<?, ?it/s]
# test_data:   0%|          | 0/59 [00:00<?, ?it/s]
# Min-max scaling.
# Standard scaling.
# /home/datamake117/.local/lib/python3.9/site-packages/numpy/lib/function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/utils/extmath.py:1051: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/utils/extmath.py:1056: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/utils/extmath.py:1076: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# /home/datamake117/.local/lib/python3.9/site-packages/numpy/lib/function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# KFold training.
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2025/02/18 17:16:39 train.py INFO Period2, Train0, Train Period:20210101-20230101, Val Period:20230101-20230331, Test Period:20230401-20230701
# 2025/02/18 17:16:39 train.py INFO Train1 Shape: torch.Size([434, 5243, 2221]), Val1 Shape: torch.Size([108, 5243, 2221]), Test1 Shape: torch.Size([59, 5243, 2221])
# 2025/02/18 17:16:39 train.py INFO Start Training
# 2025/02/18 17:18:14 train.py INFO Epoch[1/200], Time:95.42sec, Train Loss: 0.915793, Val Loss: 0.8871684074401855,0.8913508653640747,0.894491970539093,0.8872000575065613,0.8887556195259094,0.8873003721237183
# 2025/02/18 17:18:14 model.py INFO Validation loss decreased (inf --> 0.887168).  Saving model 0.0...
# 2025/02/18 17:18:14 model.py INFO Validation loss decreased (inf --> 0.891351).  Saving model 1.0...
# 2025/02/18 17:18:14 model.py INFO Validation loss decreased (inf --> 0.894492).  Saving model 2.0...
# 2025/02/18 17:18:14 model.py INFO Validation loss decreased (inf --> 0.887200).  Saving model 3.0...
# 2025/02/18 17:18:14 model.py INFO Validation loss decreased (inf --> 0.888756).  Saving model 4.0...
# 2025/02/18 17:18:14 model.py INFO Validation loss decreased (inf --> 0.887300).  Saving model 5.0...
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2025/02/18 17:19:33 train.py INFO Period2, Train1, Train Period:20210101-20230101, Val Period:20230101-20230331, Test Period:20230401-20230701
# 2025/02/18 17:19:33 train.py INFO Train1 Shape: torch.Size([434, 5243, 2221]), Val1 Shape: torch.Size([108, 5243, 2221]), Test1 Shape: torch.Size([59, 5243, 2221])
# 2025/02/18 17:19:33 train.py INFO Start Training
# 2025/02/18 17:20:04 train.py INFO Epoch[2/200], Time:109.62sec, Train Loss: 0.885024, Val Loss: 0.8818046450614929,0.8831580877304077,0.8822100758552551,0.8793355822563171,0.8789129257202148,0.8768905401229858
# 2025/02/18 17:20:04 model.py INFO Validation loss decreased (0.887168 --> 0.881805).  Saving model 0.0...
# 2025/02/18 17:20:04 model.py INFO Validation loss decreased (0.891351 --> 0.883158).  Saving model 1.0...
# 2025/02/18 17:20:04 model.py INFO Validation loss decreased (0.894492 --> 0.882210).  Saving model 2.0...
# 2025/02/18 17:20:04 model.py INFO Validation loss decreased (0.887200 --> 0.879336).  Saving model 3.0...
# 2025/02/18 17:20:04 model.py INFO Validation loss decreased (0.888756 --> 0.878913).  Saving model 4.0...
# 2025/02/18 17:20:04 model.py INFO Validation loss decreased (0.887300 --> 0.876891).  Saving model 5.0...
# 2025/02/18 17:21:28 train.py INFO Epoch[1/200], Time:115.18sec, Train Loss: 0.915136, Val Loss: 0.9059281945228577,0.9184094667434692,0.9094182252883911,0.9061196446418762,0.922886312007904,0.9057296514511108
# 2025/02/18 17:21:28 model.py INFO Validation loss decreased (inf --> 0.905928).  Saving model 0.0...
# 2025/02/18 17:21:28 model.py INFO Validation loss decreased (inf --> 0.918409).  Saving model 1.0...
# 2025/02/18 17:21:28 model.py INFO Validation loss decreased (inf --> 0.909418).  Saving model 2.0...
# 2025/02/18 17:21:28 model.py INFO Validation loss decreased (inf --> 0.906120).  Saving model 3.0...
# 2025/02/18 17:21:28 model.py INFO Validation loss decreased (inf --> 0.922886).  Saving model 4.0...
# 2025/02/18 17:21:28 model.py INFO Validation loss decreased (inf --> 0.905730).  Saving model 5.0...
# 2025/02/18 17:21:59 train.py INFO Epoch[3/200], Time:114.90sec, Train Loss: 0.872754, Val Loss: 0.8839575052261353,0.8732879161834717,0.8702985644340515,0.8766282796859741,0.868038535118103,0.8720478415489197
# 2025/02/18 17:21:59 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:21:59 model.py INFO Validation loss decreased (0.883158 --> 0.873288).  Saving model 1.0...
# 2025/02/18 17:21:59 model.py INFO Validation loss decreased (0.882210 --> 0.870299).  Saving model 2.0...
# 2025/02/18 17:21:59 model.py INFO Validation loss decreased (0.879336 --> 0.876628).  Saving model 3.0...
# 2025/02/18 17:21:59 model.py INFO Validation loss decreased (0.878913 --> 0.868039).  Saving model 4.0...
# 2025/02/18 17:21:59 model.py INFO Validation loss decreased (0.876891 --> 0.872048).  Saving model 5.0...
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2025/02/18 17:23:07 train.py INFO Period2, Train2, Train Period:20210101-20230101, Val Period:20230101-20230331, Test Period:20230401-20230701
# 2025/02/18 17:23:07 train.py INFO Train1 Shape: torch.Size([434, 5243, 2221]), Val1 Shape: torch.Size([108, 5243, 2221]), Test1 Shape: torch.Size([59, 5243, 2221])
# 2025/02/18 17:23:07 train.py INFO Start Training
# 2025/02/18 17:23:34 train.py INFO Epoch[2/200], Time:126.05sec, Train Loss: 0.881010, Val Loss: 0.8950233459472656,0.9105051755905151,0.9072373509407043,0.8966274857521057,0.9057725667953491,0.9081385731697083
# 2025/02/18 17:23:34 model.py INFO Validation loss decreased (0.905928 --> 0.895023).  Saving model 0.0...
# 2025/02/18 17:23:34 model.py INFO Validation loss decreased (0.918409 --> 0.910505).  Saving model 1.0...
# 2025/02/18 17:23:35 model.py INFO Validation loss decreased (0.909418 --> 0.907237).  Saving model 2.0...
# 2025/02/18 17:23:35 model.py INFO Validation loss decreased (0.906120 --> 0.896627).  Saving model 3.0...
# 2025/02/18 17:23:35 model.py INFO Validation loss decreased (0.922886 --> 0.905773).  Saving model 4.0...
# 2025/02/18 17:23:35 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:24:09 train.py INFO Epoch[4/200], Time:130.18sec, Train Loss: 0.863318, Val Loss: 0.8850847482681274,0.8713088035583496,0.8661540150642395,0.8789575099945068,0.8626090288162231,0.8637672066688538
# 2025/02/18 17:24:09 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:24:09 model.py INFO Validation loss decreased (0.873288 --> 0.871309).  Saving model 1.0...
# 2025/02/18 17:24:09 model.py INFO Validation loss decreased (0.870299 --> 0.866154).  Saving model 2.0...
# 2025/02/18 17:24:09 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:24:09 model.py INFO Validation loss decreased (0.868039 --> 0.862609).  Saving model 4.0...
# 2025/02/18 17:24:09 model.py INFO Validation loss decreased (0.872048 --> 0.863767).  Saving model 5.0...
# 2025/02/18 17:25:09 train.py INFO Epoch[1/200], Time:121.92sec, Train Loss: 0.917813, Val Loss: 0.8924018740653992,0.9048874378204346,0.894538402557373,0.8860955834388733,0.8968061804771423,0.8940268754959106
# 2025/02/18 17:25:09 model.py INFO Validation loss decreased (inf --> 0.892402).  Saving model 0.0...
# 2025/02/18 17:25:09 model.py INFO Validation loss decreased (inf --> 0.904887).  Saving model 1.0...
# 2025/02/18 17:25:09 model.py INFO Validation loss decreased (inf --> 0.894538).  Saving model 2.0...
# 2025/02/18 17:25:09 model.py INFO Validation loss decreased (inf --> 0.886096).  Saving model 3.0...
# 2025/02/18 17:25:09 model.py INFO Validation loss decreased (inf --> 0.896806).  Saving model 4.0...
# 2025/02/18 17:25:09 model.py INFO Validation loss decreased (inf --> 0.894027).  Saving model 5.0...
# 2025/02/18 17:25:34 train.py INFO Epoch[3/200], Time:119.55sec, Train Loss: 0.868427, Val Loss: 0.891178548336029,0.897942304611206,0.903794527053833,0.8913881778717041,0.8935073018074036,0.9137803912162781
# 2025/02/18 17:25:34 model.py INFO Validation loss decreased (0.895023 --> 0.891179).  Saving model 0.0...
# 2025/02/18 17:25:34 model.py INFO Validation loss decreased (0.910505 --> 0.897942).  Saving model 1.0...
# 2025/02/18 17:25:34 model.py INFO Validation loss decreased (0.907237 --> 0.903795).  Saving model 2.0...
# 2025/02/18 17:25:34 model.py INFO Validation loss decreased (0.896627 --> 0.891388).  Saving model 3.0...
# 2025/02/18 17:25:34 model.py INFO Validation loss decreased (0.905773 --> 0.893507).  Saving model 4.0...
# 2025/02/18 17:25:34 model.py INFO EarlyStopping counter: 2 out of 10
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2025/02/18 17:26:28 train.py INFO Epoch[5/200], Time:139.18sec, Train Loss: 0.854830, Val Loss: 0.9035742878913879,0.8687450885772705,0.8669034242630005,0.9007757902145386,0.8633575439453125,0.8630914688110352
# 2025/02/18 17:26:28 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 17:26:28 model.py INFO Validation loss decreased (0.871309 --> 0.868745).  Saving model 1.0...
# 2025/02/18 17:26:29 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:26:29 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:26:29 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:26:29 model.py INFO Validation loss decreased (0.863767 --> 0.863091).  Saving model 5.0...
# 2025/02/18 17:26:30 train.py INFO Period2, Train3, Train Period:20210101-20230101, Val Period:20230101-20230331, Test Period:20230401-20230701
# 2025/02/18 17:26:30 train.py INFO Train1 Shape: torch.Size([435, 5243, 2221]), Val1 Shape: torch.Size([107, 5243, 2221]), Test1 Shape: torch.Size([59, 5243, 2221])
# 2025/02/18 17:26:30 train.py INFO Start Training
# 2025/02/18 17:27:33 train.py INFO Epoch[2/200], Time:144.18sec, Train Loss: 0.882147, Val Loss: 0.8826895356178284,0.8914102911949158,0.8821106553077698,0.882760763168335,0.8909327983856201,0.8815873861312866
# 2025/02/18 17:27:33 model.py INFO Validation loss decreased (0.892402 --> 0.882690).  Saving model 0.0...
# 2025/02/18 17:27:33 model.py INFO Validation loss decreased (0.904887 --> 0.891410).  Saving model 1.0...
# 2025/02/18 17:27:33 model.py INFO Validation loss decreased (0.894538 --> 0.882111).  Saving model 2.0...
# 2025/02/18 17:27:33 model.py INFO Validation loss decreased (0.886096 --> 0.882761).  Saving model 3.0...
# 2025/02/18 17:27:33 model.py INFO Validation loss decreased (0.896806 --> 0.890933).  Saving model 4.0...
# 2025/02/18 17:27:33 model.py INFO Validation loss decreased (0.894027 --> 0.881587).  Saving model 5.0...
# 2025/02/18 17:28:01 train.py INFO Epoch[4/200], Time:146.78sec, Train Loss: 0.859374, Val Loss: 0.8882644772529602,0.896131157875061,0.9159826636314392,0.8863604068756104,0.8908793926239014,0.9132512807846069
# 2025/02/18 17:28:01 model.py INFO Validation loss decreased (0.891179 --> 0.888264).  Saving model 0.0...
# 2025/02/18 17:28:01 model.py INFO Validation loss decreased (0.897942 --> 0.896131).  Saving model 1.0...
# 2025/02/18 17:28:01 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:28:01 model.py INFO Validation loss decreased (0.891388 --> 0.886360).  Saving model 3.0...
# 2025/02/18 17:28:01 model.py INFO Validation loss decreased (0.893507 --> 0.890879).  Saving model 4.0...
# 2025/02/18 17:28:01 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 17:28:45 train.py INFO Epoch[1/200], Time:134.22sec, Train Loss: 0.915010, Val Loss: 0.8972023725509644,0.9066580533981323,0.8996179103851318,0.9009925723075867,0.908431351184845,0.9008951783180237
# 2025/02/18 17:28:45 model.py INFO Validation loss decreased (inf --> 0.897202).  Saving model 0.0...
# 2025/02/18 17:28:45 model.py INFO Validation loss decreased (inf --> 0.906658).  Saving model 1.0...
# 2025/02/18 17:28:45 model.py INFO Validation loss decreased (inf --> 0.899618).  Saving model 2.0...
# 2025/02/18 17:28:45 model.py INFO Validation loss decreased (inf --> 0.900993).  Saving model 3.0...
# 2025/02/18 17:28:45 model.py INFO Validation loss decreased (inf --> 0.908431).  Saving model 4.0...
# 2025/02/18 17:28:45 model.py INFO Validation loss decreased (inf --> 0.900895).  Saving model 5.0...
# 2025/02/18 17:28:48 train.py INFO Epoch[6/200], Time:139.03sec, Train Loss: 0.846356, Val Loss: 0.9139135479927063,0.8697985410690308,0.8655037879943848,0.9041892290115356,0.864141583442688,0.863084077835083
# 2025/02/18 17:28:48 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/02/18 17:28:48 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:28:48 model.py INFO Validation loss decreased (0.866154 --> 0.865504).  Saving model 2.0...
# 2025/02/18 17:28:48 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 17:28:48 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:28:48 model.py INFO Validation loss decreased (0.863091 --> 0.863084).  Saving model 5.0...
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2025/02/18 17:29:51 train.py INFO Epoch[3/200], Time:137.92sec, Train Loss: 0.868221, Val Loss: 0.8769975900650024,0.8902645707130432,0.8768824934959412,0.8788601756095886,0.8869403600692749,0.874828577041626
# 2025/02/18 17:29:51 model.py INFO Validation loss decreased (0.882690 --> 0.876998).  Saving model 0.0...
# 2025/02/18 17:29:51 model.py INFO Validation loss decreased (0.891410 --> 0.890265).  Saving model 1.0...
# 2025/02/18 17:29:51 model.py INFO Validation loss decreased (0.882111 --> 0.876882).  Saving model 2.0...
# 2025/02/18 17:29:51 model.py INFO Validation loss decreased (0.882761 --> 0.878860).  Saving model 3.0...
# 2025/02/18 17:29:51 model.py INFO Validation loss decreased (0.890933 --> 0.886940).  Saving model 4.0...
# 2025/02/18 17:29:51 model.py INFO Validation loss decreased (0.881587 --> 0.874829).  Saving model 5.0...
# 2025/02/18 17:30:30 train.py INFO Epoch[5/200], Time:148.91sec, Train Loss: 0.851766, Val Loss: 0.8857629895210266,0.8886547684669495,0.9126079678535461,0.8879239559173584,0.8913100957870483,0.927584707736969
# 2025/02/18 17:30:30 model.py INFO Validation loss decreased (0.888264 --> 0.885763).  Saving model 0.0...
# 2025/02/18 17:30:30 model.py INFO Validation loss decreased (0.896131 --> 0.888655).  Saving model 1.0...
# 2025/02/18 17:30:30 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:30:30 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:30:30 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:30:30 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/02/18 17:30:31 train.py INFO Period2, Train4, Train Period:20210101-20230101, Val Period:20230101-20230331, Test Period:20230401-20230701
# 2025/02/18 17:30:31 train.py INFO Train1 Shape: torch.Size([435, 5243, 2221]), Val1 Shape: torch.Size([107, 5243, 2221]), Test1 Shape: torch.Size([59, 5243, 2221])
# 2025/02/18 17:30:31 train.py INFO Start Training
# 2025/02/18 17:31:16 train.py INFO Epoch[2/200], Time:151.34sec, Train Loss: 0.881473, Val Loss: 0.897911548614502,0.9006450176239014,0.8951558470726013,0.8983304500579834,0.9051462411880493,0.8913139700889587
# 2025/02/18 17:31:16 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:31:16 model.py INFO Validation loss decreased (0.906658 --> 0.900645).  Saving model 1.0...
# 2025/02/18 17:31:16 model.py INFO Validation loss decreased (0.899618 --> 0.895156).  Saving model 2.0...
# 2025/02/18 17:31:16 model.py INFO Validation loss decreased (0.900993 --> 0.898330).  Saving model 3.0...
# 2025/02/18 17:31:16 model.py INFO Validation loss decreased (0.908431 --> 0.905146).  Saving model 4.0...
# 2025/02/18 17:31:16 model.py INFO Validation loss decreased (0.900895 --> 0.891314).  Saving model 5.0...
# 2025/02/18 17:31:23 train.py INFO Epoch[7/200], Time:155.07sec, Train Loss: 0.837428, Val Loss: 0.9343966841697693,0.8749375343322754,0.865066647529602,0.9196659922599792,0.8649747371673584,0.8639056086540222
# 2025/02/18 17:31:23 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/02/18 17:31:23 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:31:23 model.py INFO Validation loss decreased (0.865504 --> 0.865067).  Saving model 2.0...
# 2025/02/18 17:31:23 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/02/18 17:31:23 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 17:31:23 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:32:32 train.py INFO Epoch[4/200], Time:161.00sec, Train Loss: 0.858209, Val Loss: 0.8732289671897888,0.8921231627464294,0.8752904534339905,0.8781176805496216,0.893283486366272,0.8755035996437073
# 2025/02/18 17:32:32 model.py INFO Validation loss decreased (0.876998 --> 0.873229).  Saving model 0.0...
# 2025/02/18 17:32:32 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:32:32 model.py INFO Validation loss decreased (0.876882 --> 0.875290).  Saving model 2.0...
# 2025/02/18 17:32:32 model.py INFO Validation loss decreased (0.878860 --> 0.878118).  Saving model 3.0...
# 2025/02/18 17:32:32 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:32:32 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:33:01 train.py INFO Epoch[1/200], Time:149.71sec, Train Loss: 0.917063, Val Loss: 0.8970791101455688,0.8865246772766113,0.8961631059646606,0.8997169137001038,0.8869540691375732,0.8939249515533447
# 2025/02/18 17:33:01 model.py INFO Validation loss decreased (inf --> 0.897079).  Saving model 0.0...
# 2025/02/18 17:33:01 model.py INFO Validation loss decreased (inf --> 0.886525).  Saving model 1.0...
# 2025/02/18 17:33:01 model.py INFO Validation loss decreased (inf --> 0.896163).  Saving model 2.0...
# 2025/02/18 17:33:01 model.py INFO Validation loss decreased (inf --> 0.899717).  Saving model 3.0...
# 2025/02/18 17:33:01 model.py INFO Validation loss decreased (inf --> 0.886954).  Saving model 4.0...
# 2025/02/18 17:33:01 model.py INFO Validation loss decreased (inf --> 0.893925).  Saving model 5.0...
# 2025/02/18 17:33:01 train.py INFO Epoch[6/200], Time:151.17sec, Train Loss: 0.844313, Val Loss: 0.8868025541305542,0.8872978091239929,0.9143093824386597,0.8888676166534424,0.8853596448898315,0.9335224628448486
# 2025/02/18 17:33:01 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:33:01 model.py INFO Validation loss decreased (0.888655 --> 0.887298).  Saving model 1.0...
# 2025/02/18 17:33:01 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 17:33:01 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:33:01 model.py INFO Validation loss decreased (0.890879 --> 0.885360).  Saving model 4.0...
# 2025/02/18 17:33:01 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/02/18 17:33:48 train.py INFO Epoch[3/200], Time:151.66sec, Train Loss: 0.868170, Val Loss: 0.8977571725845337,0.8997026681900024,0.8945306539535522,0.9038857817649841,0.8977399468421936,0.893789529800415
# 2025/02/18 17:33:48 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:33:48 model.py INFO Validation loss decreased (0.900645 --> 0.899703).  Saving model 1.0...
# 2025/02/18 17:33:48 model.py INFO Validation loss decreased (0.895156 --> 0.894531).  Saving model 2.0...
# 2025/02/18 17:33:48 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:33:48 model.py INFO Validation loss decreased (0.905146 --> 0.897740).  Saving model 4.0...
# 2025/02/18 17:33:48 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:33:53 train.py INFO Epoch[8/200], Time:150.73sec, Train Loss: 0.826822, Val Loss: 0.9465572834014893,0.8877147436141968,0.8697611689567566,0.9144080281257629,0.8698793649673462,0.8660178184509277
# 2025/02/18 17:33:53 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/02/18 17:33:53 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 17:33:53 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:33:53 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/02/18 17:33:53 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/02/18 17:33:53 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:35:02 train.py INFO Epoch[5/200], Time:149.70sec, Train Loss: 0.849927, Val Loss: 0.8744845986366272,0.8961273431777954,0.8774091601371765,0.8778817653656006,0.9006819725036621,0.8832684755325317
# 2025/02/18 17:35:02 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:35:02 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:35:02 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:35:02 model.py INFO Validation loss decreased (0.878118 --> 0.877882).  Saving model 3.0...
# 2025/02/18 17:35:02 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:35:02 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:35:32 train.py INFO Epoch[2/200], Time:150.55sec, Train Loss: 0.881779, Val Loss: 0.9015832543373108,0.880828857421875,0.8942463397979736,0.900111198425293,0.8804932236671448,0.8855565190315247
# 2025/02/18 17:35:32 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:35:32 model.py INFO Validation loss decreased (0.886525 --> 0.880829).  Saving model 1.0...
# 2025/02/18 17:35:32 model.py INFO Validation loss decreased (0.896163 --> 0.894246).  Saving model 2.0...
# 2025/02/18 17:35:32 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:35:32 model.py INFO Validation loss decreased (0.886954 --> 0.880493).  Saving model 4.0...
# 2025/02/18 17:35:32 model.py INFO Validation loss decreased (0.893925 --> 0.885557).  Saving model 5.0...
# 2025/02/18 17:35:33 train.py INFO Epoch[7/200], Time:152.11sec, Train Loss: 0.835791, Val Loss: 0.8859905004501343,0.8813738822937012,0.9384082555770874,0.8890554904937744,0.8863139152526855,0.9387392997741699
# 2025/02/18 17:35:33 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:35:33 model.py INFO Validation loss decreased (0.887298 --> 0.881374).  Saving model 1.0...
# 2025/02/18 17:35:33 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/02/18 17:35:33 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 17:35:33 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:35:33 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/02/18 17:36:22 train.py INFO Epoch[4/200], Time:153.71sec, Train Loss: 0.858664, Val Loss: 0.9055283665657043,0.8975362181663513,0.891139030456543,0.9163955450057983,0.895527720451355,0.8912565112113953
# 2025/02/18 17:36:22 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 17:36:22 model.py INFO Validation loss decreased (0.899703 --> 0.897536).  Saving model 1.0...
# 2025/02/18 17:36:22 model.py INFO Validation loss decreased (0.894531 --> 0.891139).  Saving model 2.0...
# 2025/02/18 17:36:22 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:36:22 model.py INFO Validation loss decreased (0.897740 --> 0.895528).  Saving model 4.0...
# 2025/02/18 17:36:22 model.py INFO Validation loss decreased (0.891314 --> 0.891257).  Saving model 5.0...
# 2025/02/18 17:36:26 train.py INFO Epoch[9/200], Time:152.64sec, Train Loss: 0.813716, Val Loss: 0.956221878528595,0.8922207951545715,0.8670353293418884,0.9266123175621033,0.8767002820968628,0.8662939071655273
# 2025/02/18 17:36:26 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/02/18 17:36:26 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/02/18 17:36:26 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:36:26 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/02/18 17:36:26 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/02/18 17:36:26 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 17:37:33 train.py INFO Epoch[6/200], Time:150.71sec, Train Loss: 0.840963, Val Loss: 0.8794820308685303,0.9075307250022888,0.8785752058029175,0.8785613775253296,0.9074616432189941,0.884765625
# 2025/02/18 17:37:33 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:37:33 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 17:37:33 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:37:33 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/02/18 17:37:33 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 17:37:33 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 17:38:02 train.py INFO Epoch[3/200], Time:150.46sec, Train Loss: 0.867910, Val Loss: 0.908392071723938,0.8806111216545105,0.887972354888916,0.9084020256996155,0.8794564604759216,0.8822522759437561
# 2025/02/18 17:38:02 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:38:02 model.py INFO Validation loss decreased (0.880829 --> 0.880611).  Saving model 1.0...
# 2025/02/18 17:38:02 model.py INFO Validation loss decreased (0.894246 --> 0.887972).  Saving model 2.0...
# 2025/02/18 17:38:02 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/02/18 17:38:02 model.py INFO Validation loss decreased (0.880493 --> 0.879456).  Saving model 4.0...
# 2025/02/18 17:38:02 model.py INFO Validation loss decreased (0.885557 --> 0.882252).  Saving model 5.0...
# 2025/02/18 17:38:05 train.py INFO Epoch[8/200], Time:151.36sec, Train Loss: 0.825909, Val Loss: 0.8865306377410889,0.8816632032394409,0.9442972540855408,0.8875399827957153,0.8868587613105774,0.9603116512298584
# 2025/02/18 17:38:05 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/02/18 17
model.py INFO EarlyStopping counter: 13 out of 10
# 2025/02/19 01:01:07 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/02/19 01:01:07 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/02/19 01:01:07 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/02/19 01:01:12 train.py INFO Test Loss: 0.035655
# 2025/02/19 01:01:15 train.py INFO Finish 2 Fold.
# 2025/02/19 01:01:50 train.py INFO Epoch[15/200], Time:42.98sec, Train Loss: 0.852045, Val Loss: 0.9004905819892883,0.909334123134613,0.9825700521469116,0.9085310697555542,0.904239296913147,0.9619334936141968
# 2025/02/19 01:01:50 model.py INFO EarlyStopping counter: 13 out of 10
# 2025/02/19 01:01:50 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/02/19 01:01:50 model.py INFO EarlyStopping counter: 14 out of 10
# 2025/02/19 01:01:50 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/02/19 01:01:50 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/02/19 01:01:50 model.py INFO EarlyStopping counter: 13 out of 10
# 2025/02/19 01:01:50 train.py INFO Early stopping
# 2025/02/19 01:01:50 train.py INFO Val Loss: 0.8859286308288574,0.8820753693580627,0.9062689542770386,0.8798239231109619,0.8834645748138428,0.8989135026931763
# 2025/02/19 01:01:54 train.py INFO Test Loss: 0.036420
# 2025/02/19 01:01:58 train.py INFO Finish 4 Fold.
# Save test data.
# /tmp/ipykernel_3716635/1476732172.py:118: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   total_test_output.append(torch.load(test_path))
# /tmp/ipykernel_3716635/1457820417.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_output = torch.load("/home/datamake117/data/haris/DL/" + main_folder_name + "/test_output_" + str(round_num) + ".pt")
# /tmp/ipykernel_3716635/1457820417.py:33: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   date_pid = torch.load("/home/datamake117/data/haris/DL/" + main_folder_name + "/test_date_pid_" + str(round_num) + ".pt")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 42
#      40     grading_factor.loc[total_date_pid_test[i][0], total_date_pid_test[i][1]] = test_output_list[i]
#      41 grading_factor2023 = pd.read_pickle("/home/datamake117/data/haris/DL/" + main_folder_name + "/单次_KFold_2023.pkl")
# ---> 42 grading_factor2023 = grading_factor2023[grading_factor2023.index < pd.to_datetime('2023-04-01')]
#      43 grading_factor = pd.concat([grading_factor2023, grading_factor], axis=0)
#      44 grading_factor.to_pickle("/home/datamake117/data/haris/DL/" + main_folder_name + "/单次_KFold_0.pkl")
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py:7120, in Index._cmp_method(self, other, op)
#    7116     result = op(self._values, other)
#    7118 elif is_object_dtype(self.dtype) and not isinstance(self, ABCMultiIndex):
#    7119     # don't pass MultiIndex
# -> 7120     result = ops.comp_method_OBJECT_ARRAY(op, self._values, other)
#    7122 else:
#    7123     result = ops.comparison_op(self._values, other, op)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:131, in comp_method_OBJECT_ARRAY(op, x, y)
#     129     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     130 else:
# --> 131     result = libops.scalar_compare(x.ravel(), y, op)
#     132 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'int' and 'Timestamp'
