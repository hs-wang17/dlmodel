# %%
import os
import random
import gc
import pandas as pd
import numpy as np
from dateutil.relativedelta import relativedelta
from tqdm.notebook import tqdm, trange
import torch
import torch.multiprocessing as mp
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler

from methods.model import *
from methods.logger import *
from methods.processing import *
from methods.train import *

# %% [markdown]
# # 读取数据

# %%
mp.set_start_method('spawn', force=True)
main_device_name = 0
print('Read Factor.')
factor = pd.read_pickle('/home/datamake134/data/haris/dataset/total_date.pkl')                      # 日期+股票代码
grouped = pd.read_pickle('/home/datamake134/data/haris/dataset/grouped_adj.pkl').fillna(0)          # 特征
grouped_label = pd.read_pickle('/home/datamake134/data/haris/dataset/grouped_label_adj.pkl')        # 标签
grouped_liquidity = pd.read_pickle('/home/datamake134/data/haris/dataset/grouped_liquidity.pkl')    # 流动性指标
grouped_liquidity.index = grouped_liquidity.index.strftime('%Y%m%d').astype(int)
correlation_df = pd.read_pickle('/home/datamake134/data/haris/dataset/corr_byday_abs.pkl')          # 因子筛选辅助数据
# correlation_df.index = correlation_df.index.strftime('%Y%m%d').astype(int)
total_date_list = np.array(factor['date'].drop_duplicates().tolist())                               # 日期列表
# Out:
# Read Factor.

# %%
def main(
    round_num, dt1, dt2, dt3, dt4, dt5,
    correlation_df, grouped, grouped_label, grouped_liquidity,
    total_date_list, main_folder_name, 
    pid_num=5255, factor_num=2790, corr_thres=0.9, seed_num=5, model_mode=False, multi_model=6
    ):
    '''
    para round_num: 轮数（周期序号）
    para dt1: 训练集开始时间
    para dt2: 验证集开始时间
    para dt3: 验证集结束时间
    para dt4: 测试集开始时间
    para dt5: 测试集结束时间
    
    dt1 ------训练集------ dt2 ------验证集------ dt3/dt4 ------测试集------ dt5
    
    para correlation_df: 因子筛选辅助数据
    para grouped: 按日期分组的因子数据
    para grouped_label: 按日期分组的标签数据
    para grouped_liquidity: 按日期分组的流动性数据
    para total_date_list: 全部日期
    para main_folder_name: 主文件夹名称
    para pid_num: 股票数量
    para factor_num: 因子数量
    para corr_thres: 因子筛选相关系数阈值
    para seed_num: 每个模型的种子数
    para model_mode: 是否继续训练
    para multi_model: 模型数量
    '''
    seed_list = []
    for i in range(seed_num):
        random.seed(i)
        seed_list.append(list(random.sample(range(100), multi_model)))
    total_train_num = len(seed_list)  # seed_num * multi_model
    total_test_output = []
    total_test_name = 'test_output_' + str(round_num) + '.pt'
    total_date_pid_name = 'test_date_pid_' + str(round_num) + '.pt'
    save_path = "/home/datamake134/data/haris/DL/" + main_folder_name
    
    # 根据给定的时间范围 dt1 到 dt3，选出训练集的日期列表。之后，有一个特别的日期范围处理（过滤掉指定日期段的训练数据）。
    date_list_train = total_date_list[np.where((total_date_list >= dt1) & (total_date_list < dt3))[0]]
    # 若20240223在训练周期或测试周期内，训练周期或测试周期去除20240201-20240223这一时间段
    if 20240223 >= dt1 and 20240223 <= dt3:
        date_list_train = np.array([date_train for date_train in date_list_train if date_train < 20240201 or date_train > 20240223])
    total_ts_train_val1 = np.zeros((len(date_list_train), pid_num, factor_num)) # 因子数据 shape: (len(date_list_train), pid_num, factor_num)
    total_label_train_val = np.zeros((len(date_list_train), pid_num, 5))        # 标签数据 shape: (len(date_list_train), pid_num, 5)
    total_group_train_val = np.zeros((len(date_list_train), pid_num, 1))        # 流动性数据 shape: (len(date_list_train), pid_num, 1)
    for i in trange(len(date_list_train), desc='train_val_data'):
        date = date_list_train[i]
        total_ts_train_val1[i, :, :] = grouped.loc[date].iloc[:pid_num, :]          # 因子
        total_label_train_val[i, :, :] = grouped_label.loc[date].iloc[:pid_num, :]  # 标签
        # 根据流动性调整收益率前7%-10%附近的训练标签：label(returns)
        total_label_train_val[i, :, 0] = adjust_daily_returns(total_label_train_val[i, :, 0], total_label_train_val[i, :, 4])
        total_group_train_val[i, :, :] = np.array(grouped_liquidity.loc[date])[:pid_num].reshape(-1, 1)  # 流动性
    
    # 类似地，date_list_test 被定义为测试集的日期范围，时间从 dt4 到 dt5。
    date_list_test = total_date_list[np.where((total_date_list >= dt4) & (total_date_list < dt5))[0]]
    total_ts_test1 = np.zeros((len(date_list_test), pid_num, factor_num))
    total_label_test = np.zeros((len(date_list_test), pid_num, 5))
    total_group_test = np.zeros((len(date_list_test), pid_num, 1))
    for i in trange(len(date_list_test), desc='test_data'):
        date = date_list_test[i]
        total_ts_test1[i, :, :] = grouped.loc[date].iloc[:pid_num, :]
        total_label_test[i, :, :] = grouped_label.loc[date].iloc[:pid_num, :]
        total_label_test[i, :, 0] = adjust_daily_returns(total_label_test[i, :, 0], total_label_test[i, :, 4])
        total_group_test[i, :, :] = np.array(grouped_liquidity.loc[date])[:pid_num].reshape(-1, 1)
    
    # 流动性数据归一化
    def min_max_standard(column):
        return (column - column.min()) / (column.max() - column.min())
    print('Min-max scaling.')
    total_group_train_val, total_group_test = min_max_standard(total_group_train_val), min_max_standard(total_group_test)
    
    # 因子数据标准化
    print('Standard scaling.')
    scaler = StandardScaler()
    total_ts_train_val1 = np.apply_along_axis(
        lambda x: np.clip(x, np.percentile(x, 0.5), np.percentile(x, 99.5)), axis=0, arr=total_ts_train_val1.reshape(-1, factor_num)
        )  # 去极值，保留0.5%-99.5%数据
    total_ts_train_val1 = total_ts_train_val1.reshape(len(date_list_train), pid_num, factor_num)
    total_ts_train_val1 = np.nan_to_num(scaler.fit_transform(total_ts_train_val1.reshape(-1, factor_num)).reshape(len(date_list_train), pid_num, factor_num), nan=0)
    total_ts_test1 = np.apply_along_axis(
        lambda x: np.clip(x, np.percentile(x, 0.5), np.percentile(x, 99.5)), axis=0, arr=total_ts_test1.reshape(-1, factor_num)
        )
    total_ts_test1 = total_ts_test1.reshape(len(date_list_test), pid_num, factor_num)
    total_ts_test1 = np.nan_to_num(scaler.transform(total_ts_test1.reshape(-1, factor_num)).reshape(len(date_list_test), pid_num, factor_num), nan=0)
    
    # KFold 交叉验证（并行训练）
    print('KFold training.')
    kf = KFold(n_splits=total_train_num, shuffle=False)
    processes = []
    for train_num, index_tuple in enumerate(kf.split(total_ts_train_val1)):
        p = mp.Process(
            target=train_one_Fold, 
            args=(
                round_num, train_num, index_tuple, main_folder_name,
                total_ts_train_val1, total_label_train_val, total_group_train_val, date_list_train,
                total_ts_test1, total_label_test, total_group_test, date_list_test,
                correlation_df, seed_list, dt1, dt2, dt3, dt4, dt5,
                factor_num, corr_thres, save_path, model_mode, multi_model
                )
            )
        processes.append(p)
        p.start()
    for p in processes:
        p.join()
    
    torch.cuda.empty_cache()
    gc.collect()
    
    # 保存测试数据
    print('Save test data.')
    total_test_output = []
    for train_num in range(total_train_num):
        test_name = 'test_output_ic' + str(round_num) + str(train_num) + '.pt'
        test_path = os.path.join(save_path, test_name)
        total_test_output.append(torch.load(test_path))
        
    total_test_path = os.path.join(save_path, total_test_name)
    total_date_pid_path = os.path.join(save_path, total_date_pid_name)
    
    total_test_output = torch.stack(total_test_output)
    weight_tensor = torch.tensor([0.1, 0.15, 0.2, 0.25, 0.3]).view(-1, *([1] * (total_test_output.dim() - 1)))
    total_test_output = (total_test_output * weight_tensor).sum(dim=0)
    torch.save(total_test_output, total_test_path)
    
    stocks = np.array(grouped_label.loc[20200102].index)
    repeated_stocks = np.tile(stocks, len(date_list_test))
    repeated_dates = np.repeat(date_list_test, len(stocks))
    date_pid_test = np.column_stack((repeated_dates, repeated_stocks))
    torch.save(date_pid_test, total_date_pid_path)
    
    del total_ts_train_val1
    del total_ts_test1
    del total_label_train_val
    del total_label_test
    del total_group_train_val
    del total_group_test
    
    torch.cuda.empty_cache()
    gc.collect()

# %% [markdown]
# # 训练和测试
#
# ```c
# Round 1. Train: 2020/07/01 2022/07/01 Validation: 2022/07/01 2022/12/30 Test: 2023/01/01 2023/07/01
# Round 2. Train: 2021/01/01 2023/01/01 Validation: 2023/01/01 2023/03/31 Test: 2023/04/01 2023/07/01
# Round 3. Train: 2021/04/01 2023/04/01 Validation: 2023/04/01 2023/06/30 Test: 2023/07/01 2023/10/01
# Round 4. Train: 2021/07/01 2023/07/01 Validation: 2023/07/01 2023/09/28 Test: 2023/10/01 2024/01/01
# Round 5. Train: 2021/10/01 2023/10/01 Validation: 2023/10/01 2023/12/29 Test: 2024/01/01 2024/04/01
# Round 6. Train: 2022/01/01 2024/01/01 Validation: 2024/01/01 2024/03/29 Test: 2024/04/01 2024/07/01
# Round 7. Train: 2022/04/01 2024/04/01 Validation: 2024/04/01 2024/06/28 Test: 2024/07/01 2024/10/01
# Round 8. Train: 2022/07/01 2024/07/01 Validation: 2024/07/01 2024/09/30 Test: 2024/10/01 2025/01/01
# Round 9. Train: 2022/10/01 2024/10/01 Validation: 2024/10/01 2024/12/31 Test: 2025/01/01 2025/02/21
# ```

# %%
folder_path = "/home/datamake134/data/haris/DL/" + main_folder_name
os.makedirs(folder_path, exist_ok=True)

# 第1轮
print('Round 1.')
round_num = 1
dt1 = int(pd.to_datetime("2020-07-01").strftime('%Y%m%d'))  # 训练集开始时间
dt2 = int(pd.to_datetime("2022-07-01").strftime('%Y%m%d'))  # 验证集开始时间
dt3 = int(pd.to_datetime("2022-12-30").strftime('%Y%m%d'))  # 验证集结束时间
dt4 = int(pd.to_datetime("2023-01-01").strftime('%Y%m%d'))  # 测试集开始时间
dt5 = int(pd.to_datetime("2023-04-01").strftime('%Y%m%d'))  # 测试集结束时间
main(
    round_num, dt1, dt2, dt3, dt4, dt5,
    correlation_df, grouped, grouped_label, grouped_liquidity,
    total_date_list, main_folder_name, corr_thres=0.9
    )
torch.cuda.empty_cache()
gc.collect()

test_output1 = torch.load("/home/datamake134/data/haris/DL/" + main_folder_name + "/test_output_1.pt")
test_output = torch.cat([test_output1])
test_output = test_output.cpu()
date_pid1 = torch.load("/home/datamake134/data/haris/DL/" + main_folder_name + "/test_date_pid_1.pt", weights_only=False)
total_date_pid = np.concatenate([date_pid1], axis=0)
total_date_pid_test = total_date_pid
grading_factor = pd.DataFrame(index=np.unique(total_date_pid_test[:, 0]), columns=np.unique(total_date_pid_test[:, 1]))
test_output_list = test_output.tolist()
for i in range(len(total_date_pid_test)):
    grading_factor.loc[total_date_pid_test[i][0], total_date_pid_test[i][1]] = test_output_list[i]
grading_factor.to_pickle("/home/datamake134/data/haris/DL/" + main_folder_name + "/单次_KFold_2023.pkl")
gc.collect()
# Out:
# Round 1.
# train_val_data:   0%|          | 0/610 [00:00<?, ?it/s]
# test_data:   0%|          | 0/59 [00:00<?, ?it/s]
# Min-max scaling.
# Standard scaling.
# /home/datamake134/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /home/datamake134/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:1137: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /home/datamake134/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:1142: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /home/datamake134/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:1162: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# /home/datamake134/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# KFold training.
# 2025/03/06 08:37:03 train.py INFO Period1, Train0, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230401
# 2025/03/06 08:37:03 train.py INFO Train1 Shape: torch.Size([488, 5255, 2790]), Val1 Shape: torch.Size([121, 5255, 2790]), Test1 Shape: torch.Size([59, 5255, 2790])
# 2025/03/06 08:37:03 train.py INFO Start Training
# 2025/03/06 08:40:05 train.py INFO Epoch[1/200], Time:181.44sec, Train Loss: 0.594883, Val Loss: 0.995032548904419,0.8754940629005432,0.86161208152771,0.8662595748901367,0.8708493709564209,1.0182453393936157
# 2025/03/06 08:40:05 model.py INFO Validation loss decreased (inf --> 0.995033).  Saving model 0.0...
# 2025/03/06 08:40:05 model.py INFO Validation loss decreased (inf --> 0.875494).  Saving model 1.0...
# 2025/03/06 08:40:05 model.py INFO Validation loss decreased (inf --> 0.861612).  Saving model 2.0...
# 2025/03/06 08:40:06 model.py INFO Validation loss decreased (inf --> 0.866260).  Saving model 3.0...
# 2025/03/06 08:40:06 model.py INFO Validation loss decreased (inf --> 0.870849).  Saving model 4.0...
# 2025/03/06 08:40:06 model.py INFO Validation loss decreased (inf --> 1.018245).  Saving model 5.0...
# 2025/03/06 08:42:06 train.py INFO Period1, Train1, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230401
# 2025/03/06 08:42:06 train.py INFO Train1 Shape: torch.Size([488, 5255, 2790]), Val1 Shape: torch.Size([121, 5255, 2790]), Test1 Shape: torch.Size([59, 5255, 2790])
# 2025/03/06 08:42:06 train.py INFO Start Training
# 2025/03/06 08:43:04 train.py INFO Epoch[2/200], Time:177.44sec, Train Loss: 0.574109, Val Loss: 0.9929028749465942,0.864287257194519,0.8514424562454224,0.8544723987579346,0.862591028213501,1.0095198154449463
# 2025/03/06 08:43:04 model.py INFO Validation loss decreased (0.995033 --> 0.992903).  Saving model 0.0...
# 2025/03/06 08:43:04 model.py INFO Validation loss decreased (0.875494 --> 0.864287).  Saving model 1.0...
# 2025/03/06 08:43:04 model.py INFO Validation loss decreased (0.861612 --> 0.851442).  Saving model 2.0...
# 2025/03/06 08:43:04 model.py INFO Validation loss decreased (0.866260 --> 0.854472).  Saving model 3.0...
# 2025/03/06 08:43:04 model.py INFO Validation loss decreased (0.870849 --> 0.862591).  Saving model 4.0...
# 2025/03/06 08:43:05 model.py INFO Validation loss decreased (1.018245 --> 1.009520).  Saving model 5.0...
# 2025/03/06 08:44:47 train.py INFO Epoch[1/200], Time:160.67sec, Train Loss: 0.595184, Val Loss: 0.9977277517318726,0.8689215183258057,0.8659275770187378,0.8748698234558105,0.8680596351623535,1.018344759941101
# 2025/03/06 08:44:47 model.py INFO Validation loss decreased (inf --> 0.997728).  Saving model 0.0...
# 2025/03/06 08:44:47 model.py INFO Validation loss decreased (inf --> 0.868922).  Saving model 1.0...
# 2025/03/06 08:44:47 model.py INFO Validation loss decreased (inf --> 0.865928).  Saving model 2.0...
# 2025/03/06 08:44:47 model.py INFO Validation loss decreased (inf --> 0.874870).  Saving model 3.0...
# 2025/03/06 08:44:48 model.py INFO Validation loss decreased (inf --> 0.868060).  Saving model 4.0...
# 2025/03/06 08:44:48 model.py INFO Validation loss decreased (inf --> 1.018345).  Saving model 5.0...
# 2025/03/06 08:45:43 train.py INFO Epoch[3/200], Time:158.18sec, Train Loss: 0.564424, Val Loss: 0.9648249745368958,0.8577107191085815,0.8497108221054077,0.8534612059593201,0.8576025366783142,1.0157147645950317
# 2025/03/06 08:45:43 model.py INFO Validation loss decreased (0.992903 --> 0.964825).  Saving model 0.0...
# 2025/03/06 08:45:43 model.py INFO Validation loss decreased (0.864287 --> 0.857711).  Saving model 1.0...
# 2025/03/06 08:45:43 model.py INFO Validation loss decreased (0.851442 --> 0.849711).  Saving model 2.0...
# 2025/03/06 08:45:43 model.py INFO Validation loss decreased (0.854472 --> 0.853461).  Saving model 3.0...
# 2025/03/06 08:45:43 model.py INFO Validation loss decreased (0.862591 --> 0.857603).  Saving model 4.0...
# 2025/03/06 08:45:44 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:47:25 train.py INFO Period1, Train2, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230401
# 2025/03/06 08:47:25 train.py INFO Train1 Shape: torch.Size([488, 5255, 2790]), Val1 Shape: torch.Size([121, 5255, 2790]), Test1 Shape: torch.Size([59, 5255, 2790])
# 2025/03/06 08:47:25 train.py INFO Start Training
# 2025/03/06 08:47:46 train.py INFO Epoch[2/200], Time:177.35sec, Train Loss: 0.573194, Val Loss: 1.0076327323913574,0.8567537665367126,0.8530412316322327,0.8712883591651917,0.853743851184845,0.9915608763694763
# 2025/03/06 08:47:46 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:47:46 model.py INFO Validation loss decreased (0.868922 --> 0.856754).  Saving model 1.0...
# 2025/03/06 08:47:46 model.py INFO Validation loss decreased (0.865928 --> 0.853041).  Saving model 2.0...
# 2025/03/06 08:47:46 model.py INFO Validation loss decreased (0.874870 --> 0.871288).  Saving model 3.0...
# 2025/03/06 08:47:46 model.py INFO Validation loss decreased (0.868060 --> 0.853744).  Saving model 4.0...
# 2025/03/06 08:47:46 model.py INFO Validation loss decreased (1.018345 --> 0.991561).  Saving model 5.0...
# 2025/03/06 08:48:44 train.py INFO Epoch[4/200], Time:180.85sec, Train Loss: 0.557296, Val Loss: 0.964385986328125,0.8561293482780457,0.8492592573165894,0.8534084558486938,0.8561673164367676,1.0094349384307861
# 2025/03/06 08:48:44 model.py INFO Validation loss decreased (0.964825 --> 0.964386).  Saving model 0.0...
# 2025/03/06 08:48:45 model.py INFO Validation loss decreased (0.857711 --> 0.856129).  Saving model 1.0...
# 2025/03/06 08:48:45 model.py INFO Validation loss decreased (0.849711 --> 0.849259).  Saving model 2.0...
# 2025/03/06 08:48:45 model.py INFO Validation loss decreased (0.853461 --> 0.853408).  Saving model 3.0...
# 2025/03/06 08:48:45 model.py INFO Validation loss decreased (0.857603 --> 0.856167).  Saving model 4.0...
# 2025/03/06 08:48:46 model.py INFO Validation loss decreased (1.009520 --> 1.009435).  Saving model 5.0...
# 2025/03/06 08:50:11 train.py INFO Epoch[1/200], Time:166.28sec, Train Loss: 0.591101, Val Loss: 0.9961039423942566,0.8909434676170349,0.8961421847343445,0.8877248764038086,0.8898591995239258,0.9987674951553345
# 2025/03/06 08:50:11 model.py INFO Validation loss decreased (inf --> 0.996104).  Saving model 0.0...
# 2025/03/06 08:50:12 model.py INFO Validation loss decreased (inf --> 0.890943).  Saving model 1.0...
# 2025/03/06 08:50:12 model.py INFO Validation loss decreased (inf --> 0.896142).  Saving model 2.0...
# 2025/03/06 08:50:12 model.py INFO Validation loss decreased (inf --> 0.887725).  Saving model 3.0...
# 2025/03/06 08:50:12 model.py INFO Validation loss decreased (inf --> 0.889859).  Saving model 4.0...
# 2025/03/06 08:50:12 model.py INFO Validation loss decreased (inf --> 0.998767).  Saving model 5.0...
# 2025/03/06 08:50:39 train.py INFO Epoch[3/200], Time:172.80sec, Train Loss: 0.562995, Val Loss: 1.0095539093017578,0.849370539188385,0.8489164113998413,0.8673744201660156,0.8474982380867004,1.0118143558502197
# 2025/03/06 08:50:39 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 08:50:39 model.py INFO Validation loss decreased (0.856754 --> 0.849371).  Saving model 1.0...
# 2025/03/06 08:50:39 model.py INFO Validation loss decreased (0.853041 --> 0.848916).  Saving model 2.0...
# 2025/03/06 08:50:40 model.py INFO Validation loss decreased (0.871288 --> 0.867374).  Saving model 3.0...
# 2025/03/06 08:50:40 model.py INFO Validation loss decreased (0.853744 --> 0.847498).  Saving model 4.0...
# 2025/03/06 08:50:40 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:51:38 train.py INFO Epoch[5/200], Time:171.62sec, Train Loss: 0.550705, Val Loss: 0.9635941386222839,0.8575488328933716,0.8467953205108643,0.8565983176231384,0.8576280474662781,1.0105297565460205
# 2025/03/06 08:51:38 model.py INFO Validation loss decreased (0.964386 --> 0.963594).  Saving model 0.0...
# 2025/03/06 08:51:38 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:51:38 model.py INFO Validation loss decreased (0.849259 --> 0.846795).  Saving model 2.0...
# 2025/03/06 08:51:38 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:51:38 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:51:38 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:53:09 train.py INFO Period1, Train3, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230401
# 2025/03/06 08:53:09 train.py INFO Train1 Shape: torch.Size([488, 5255, 2790]), Val1 Shape: torch.Size([121, 5255, 2790]), Test1 Shape: torch.Size([59, 5255, 2790])
# 2025/03/06 08:53:09 train.py INFO Start Training
# 2025/03/06 08:53:14 train.py INFO Epoch[2/200], Time:181.38sec, Train Loss: 0.568785, Val Loss: 1.0076013803482056,0.8847275972366333,0.885584831237793,0.8776518106460571,0.88490891456604,0.9908648133277893
# 2025/03/06 08:53:14 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:53:14 model.py INFO Validation loss decreased (0.890943 --> 0.884728).  Saving model 1.0...
# 2025/03/06 08:53:14 model.py INFO Validation loss decreased (0.896142 --> 0.885585).  Saving model 2.0...
# 2025/03/06 08:53:14 model.py INFO Validation loss decreased (0.887725 --> 0.877652).  Saving model 3.0...
# 2025/03/06 08:53:14 model.py INFO Validation loss decreased (0.889859 --> 0.884909).  Saving model 4.0...
# 2025/03/06 08:53:14 model.py INFO Validation loss decreased (0.998767 --> 0.990865).  Saving model 5.0...
# 2025/03/06 08:53:44 train.py INFO Epoch[4/200], Time:183.86sec, Train Loss: 0.555941, Val Loss: 1.0072121620178223,0.8473820686340332,0.8494195342063904,0.8677271604537964,0.8496838808059692,1.0085078477859497
# 2025/03/06 08:53:44 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/06 08:53:44 model.py INFO Validation loss decreased (0.849371 --> 0.847382).  Saving model 1.0...
# 2025/03/06 08:53:44 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:53:44 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:53:44 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:53:44 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 08:54:53 train.py INFO Epoch[6/200], Time:194.89sec, Train Loss: 0.544306, Val Loss: 0.9635888338088989,0.8601478934288025,0.8509089946746826,0.858299970626831,0.8581120371818542,1.0091924667358398
# 2025/03/06 08:54:53 model.py INFO Validation loss decreased (0.963594 --> 0.963589).  Saving model 0.0...
# 2025/03/06 08:54:53 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 08:54:53 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:54:53 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 08:54:53 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 08:54:53 model.py INFO Validation loss decreased (1.009435 --> 1.009192).  Saving model 5.0...
# 2025/03/06 08:56:14 train.py INFO Epoch[1/200], Time:185.14sec, Train Loss: 0.593924, Val Loss: 1.008527159690857,0.8719856142997742,0.8660634756088257,0.8733111023902893,0.8712143898010254,1.0060538053512573
# 2025/03/06 08:56:14 model.py INFO Validation loss decreased (inf --> 1.008527).  Saving model 0.0...
# 2025/03/06 08:56:14 model.py INFO Validation loss decreased (inf --> 0.871986).  Saving model 1.0...
# 2025/03/06 08:56:15 model.py INFO Validation loss decreased (inf --> 0.866063).  Saving model 2.0...
# 2025/03/06 08:56:15 model.py INFO Validation loss decreased (inf --> 0.873311).  Saving model 3.0...
# 2025/03/06 08:56:15 model.py INFO Validation loss decreased (inf --> 0.871214).  Saving model 4.0...
# 2025/03/06 08:56:15 model.py INFO Validation loss decreased (inf --> 1.006054).  Saving model 5.0...
# 2025/03/06 08:56:18 train.py INFO Epoch[3/200], Time:183.51sec, Train Loss: 0.559829, Val Loss: 1.0116592645645142,0.8800426721572876,0.8857197165489197,0.870733380317688,0.8830361366271973,0.995125412940979
# 2025/03/06 08:56:18 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 08:56:18 model.py INFO Validation loss decreased (0.884728 --> 0.880043).  Saving model 1.0...
# 2025/03/06 08:56:18 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:56:18 model.py INFO Validation loss decreased (0.877652 --> 0.870733).  Saving model 3.0...
# 2025/03/06 08:56:18 model.py INFO Validation loss decreased (0.884909 --> 0.883036).  Saving model 4.0...
# 2025/03/06 08:56:18 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:56:48 train.py INFO Epoch[5/200], Time:183.84sec, Train Loss: 0.548820, Val Loss: 1.0066605806350708,0.8463566303253174,0.8538060784339905,0.8702134490013123,0.8438169956207275,1.009325623512268
# 2025/03/06 08:56:48 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/06 08:56:48 model.py INFO Validation loss decreased (0.847382 --> 0.846357).  Saving model 1.0...
# 2025/03/06 08:56:48 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 08:56:48 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 08:56:48 model.py INFO Validation loss decreased (0.847498 --> 0.843817).  Saving model 4.0...
# 2025/03/06 08:56:48 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/06 08:58:02 train.py INFO Epoch[7/200], Time:189.12sec, Train Loss: 0.536211, Val Loss: 0.964074969291687,0.8634527921676636,0.8519192337989807,0.8623281717300415,0.8588206171989441,1.0099502801895142
# 2025/03/06 08:58:02 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:58:02 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/06 08:58:02 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 08:58:02 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/06 08:58:02 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/06 08:58:02 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:59:19 train.py INFO Epoch[2/200], Time:183.67sec, Train Loss: 0.571168, Val Loss: 1.026857852935791,0.8631457090377808,0.8603893518447876,0.868657112121582,0.8640437126159668,1.0117669105529785
# 2025/03/06 08:59:19 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:59:19 model.py INFO Validation loss decreased (0.871986 --> 0.863146).  Saving model 1.0...
# 2025/03/06 08:59:20 model.py INFO Validation loss decreased (0.866063 --> 0.860389).  Saving model 2.0...
# 2025/03/06 08:59:20 model.py INFO Validation loss decreased (0.873311 --> 0.868657).  Saving model 3.0...
# 2025/03/06 08:59:21 model.py INFO Validation loss decreased (0.871214 --> 0.864044).  Saving model 4.0...
# 2025/03/06 08:59:22 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:59:33 train.py INFO Epoch[4/200], Time:194.67sec, Train Loss: 0.553516, Val Loss: 1.0115454196929932,0.8812987208366394,0.8780663013458252,0.8704644441604614,0.881752073764801,0.9916917681694031
# 2025/03/06 08:59:33 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/06 08:59:33 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 08:59:33 model.py INFO Validation loss decreased (0.885585 --> 0.878066).  Saving model 2.0...
# 2025/03/06 08:59:33 model.py INFO Validation loss decreased (0.870733 --> 0.870464).  Saving model 3.0...
# 2025/03/06 08:59:34 model.py INFO Validation loss decreased (0.883036 --> 0.881752).  Saving model 4.0...
# 2025/03/06 08:59:34 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 08:59:57 train.py INFO Period1, Train4, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230401
# 2025/03/06 08:59:57 train.py INFO Train1 Shape: torch.Size([488, 5255, 2790]), Val1 Shape: torch.Size([121, 5255, 2790]), Test1 Shape: torch.Size([59, 5255, 2790])
# 2025/03/06 08:59:57 train.py INFO Start Training
# 2025/03/06 09:00:03 train.py INFO Epoch[6/200], Time:194.97sec, Train Loss: 0.541770, Val Loss: 1.0000983476638794,0.8466427326202393,0.8508782982826233,0.8705641627311707,0.8433131575584412,1.0087944269180298
# 2025/03/06 09:00:03 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/06 09:00:03 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 09:00:03 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/06 09:00:03 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/06 09:00:03 model.py INFO Validation loss decreased (0.843817 --> 0.843313).  Saving model 4.0...
# 2025/03/06 09:00:04 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/06 09:01:25 train.py INFO Epoch[8/200], Time:202.77sec, Train Loss: 0.527197, Val Loss: 0.9631579518318176,0.8635185956954956,0.8534895777702332,0.8651176691055298,0.8598480224609375,0.980025053024292
# 2025/03/06 09:01:25 model.py INFO Validation loss decreased (0.963589 --> 0.963158).  Saving model 0.0...
# 2025/03/06 09:01:25 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/06 09:01:25 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/06 09:01:25 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/06 09:01:25 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/06 09:01:25 model.py INFO Validation loss decreased (1.009192 --> 0.980025).  Saving model 5.0...
# 2025/03/06 09:02:36 train.py INFO Epoch[3/200], Time:193.95sec, Train Loss: 0.561557, Val Loss: 1.0274966955184937,0.8588149547576904,0.8533353805541992,0.8692039251327515,0.8597167730331421,1.0104063749313354
# 2025/03/06 09:02:36 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 09:02:36 model.py INFO Validation loss decreased (0.863146 --> 0.858815).  Saving model 1.0...
# 2025/03/06 09:02:36 model.py INFO Validation loss decreased (0.860389 --> 0.853335).  Saving model 2.0...
# 2025/03/06 09:02:36 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 09:02:36 model.py INFO Validation loss decreased (0.864044 --> 0.859717).  Saving model 4.0...
# 2025/03/06 09:02:36 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 09:02:52 train.py INFO Epoch[5/200], Time:197.86sec, Train Loss: 0.545723, Val Loss: 1.0110676288604736,0.8828265070915222,0.8755890130996704,0.8695962429046631,0.880986750125885,0.9786285758018494
# 2025/03/06 09:02:52 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/06 09:02:52 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 09:02:52 model.py INFO Validation loss decreased (0.878066 --> 0.875589).  Saving model 2.0...
# 2025/03/06 09:02:52 model.py INFO Validation loss decreased (0.870464 --> 0.869596).  Saving model 3.0...
# 2025/03/06 09:02:53 model.py INFO Validation loss decreased (0.881752 --> 0.880987).  Saving model 4.0...
# 2025/03/06 09:02:53 model.py INFO Validation loss decreased (0.990865 --> 0.978629).  Saving model 5.0...
# 2025/03/06 09:03:10 train.py INFO Epoch[1/200], Time:193.25sec, Train Loss: 0.592303, Val Loss: 0.9775694608688354,0.882761538028717,0.8788940906524658,0.8808956146240234,0.8766400814056396,1.004503607749939
# 2025/03/06 09:03:10 model.py INFO Validation loss decreased (inf --> 0.977569).  Saving model 0.0...
# 2025/03/06 09:03:10 model.py INFO Validation loss decreased (inf --> 0.882762).  Saving model 1.0...
# 2025/03/06 09:03:10 model.py INFO Validation loss decreased (inf --> 0.878894).  Saving model 2.0...
# 2025/03/06 09:03:11 model.py INFO Validation loss decreased (inf --> 0.880896).  Saving model 3.0...
# 2025/03/06 09:03:11 model.py INFO Validation loss decreased (inf --> 0.876640).  Saving model 4.0...
# 2025/03/06 09:03:11 model.py INFO Validation loss decreased (inf --> 1.004504).  Saving model 5.0...
# 2025/03/06 09:03:22 train.py INFO Epoch[7/200], Time:197.94sec, Train Loss: 0.533267, Val Loss: 0.9999297857284546,0.8506408333778381,0.8518843054771423,0.8691767454147339,0.8453426957130432,1.0107423067092896
# 2025/03/06 09:03:22 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/03/06 09:03:22 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 09:03:22 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/06 09:03:22 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/06 09:03:22 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 09:03:22 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/06 09:04:44 train.py INFO Epoch[9/200], Time:198.19sec, Train Loss: 0.514925, Val Loss: 0.9630656838417053,0.8711535334587097,0.8602059483528137,0.8672023415565491,0.8645063638687134,0.9856771230697632
# 2025/03/06 09:04:44 model.py INFO Validation loss decreased (0.963158 --> 0.963066).  Saving model 0.0...
# 2025/03/06 09:04:44 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/06 09:04:44 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/06 09:04:44 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/06 09:04:44 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/06 09:04:44 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 09:05:44 train.py INFO Epoch[4/200], Time:187.59sec, Train Loss: 0.553993, Val Loss: 1.0288819074630737,0.8552441596984863,0.8519030809402466,0.8723623752593994,0.8544610142707825,1.0102300643920898
# 2025/03/06 09:05:44 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/06 09:05:44 model.py INFO Validation loss decreased (0.858815 --> 0.855244).  Saving model 1.0...
# 2025/03/06 09:05:44 model.py INFO Validation loss decreased (0.853335 --> 0.851903).  Saving model 2.0...
# 2025/03/06 09:05:44 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/06 09:05:44 model.py INFO Validation loss decreased (0.859717 --> 0.854461).  Saving model 4.0...
# 2025/03/06 09:05:44 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/06 09:06:14 train.py INFO Epoch[6/200], Time:200.39sec, Train Loss: 0.537683, Val Loss: 1.0090070962905884,0.8821748495101929,0.8772534132003784,0.8699447512626648,0.8840703368186951,0.9896702766418457
# 2025/03/06 09:06:14 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/06 09:06:14 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/06 09:06:14 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 09:06:14 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 09:06:14 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 09:06:14 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 09:06:23 train.py INFO Epoch[2/200], Time:191.22sec, Train Loss: 0.568951, Val Loss: 0.9824403524398804,0.8684375882148743,0.8702021241188049,0.883118212223053,0.8684276342391968,0.9828168749809265
# 2025/03/06 09:06:23 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 09:06:23 model.py INFO Validation loss decreased (0.882762 --> 0.868438).  Saving model 1.0...
# 2025/03/06 09:06:23 model.py INFO Validation loss decreased (0.878894 --> 0.870202).  Saving model 2.0...
# 2025/03/06 09:06:23 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/06 09:06:23 model.py INFO Validation loss decreased (0.876640 --> 0.868428).  Saving model 4.0...
# 2025/03/06 09:06:24 model.py INFO Validation loss decreased (1.004504 --> 0.982817).  Saving model 5.0...

# %%
# 第2-9轮
total_date_list = np.array(factor['date'].drop_duplicates().tolist())
rolling_step = 3    # 3个月滚动训练
window_size = 24    # 训练集大小
val_size = 3        # 验证集大小
corr_thres = 0.9
for round_num in range(2, 10):
    print('Round %i.' % round_num)
    start_date = pd.to_datetime('2021-01-01')
    dt1 = start_date + relativedelta(months=rolling_step * (round_num - 2))             # 训练集开始时间
    dt2 = dt1 + relativedelta(months=window_size)                                       # 验证集开始时间
    dt3 = dt2 + relativedelta(months=val_size)                                          # 验证集结束时间
    dt4 = dt3                                                                           # 测试集开始时间
    dt5 = min(dt3 + relativedelta(months=rolling_step), pd.to_datetime('2025-02-21'))   # 测试集结束时间
    dt3 = total_date_list[total_date_list < int(dt3.strftime('%Y%m%d'))][-1]
    dt1, dt2, dt3, dt4, dt5 = int(dt1.strftime('%Y%m%d')), int(dt2.strftime('%Y%m%d')), int(dt3), int(dt4.strftime('%Y%m%d')), int(dt5.strftime('%Y%m%d'))
    main(
        round_num, dt1, dt2, dt3, dt4, dt5,
        correlation_df, grouped, grouped_label, grouped_liquidity,
        total_date_list, main_folder_name, corr_thres=0.9, seed_num=5, model_mode=False
        )
    torch.cuda.empty_cache()
    gc.collect()

test_output_list = []
for round_num in range(2, 10):
    test_output = torch.load("/home/datamake134/data/haris/DL/" + main_folder_name + "/test_output_" + str(round_num) + ".pt")
    test_output_list.append(test_output)
test_output = torch.cat(test_output_list)
test_output = test_output.cpu()
date_pid_list = []
for round_num in range(2, 10):
    date_pid = torch.load("/home/datamake134/data/haris/DL/" + main_folder_name + "/test_date_pid_" + str(round_num) + ".pt", weights_only=False)
    date_pid_list.append(date_pid)
total_date_pid = np.concatenate(date_pid_list, axis=0)
total_date_pid_test = total_date_pid
grading_factor = pd.DataFrame(index=np.unique(total_date_pid_test[:, 0]), columns=np.unique(total_date_pid_test[:, 1]))
test_output_list = test_output.tolist()
for i in range(len(total_date_pid_test)):
    grading_factor.loc[total_date_pid_test[i][0], total_date_pid_test[i][1]] = test_output_list[i]
grading_factor2023 = pd.read_pickle("/home/datamake134/data/haris/DL/" + main_folder_name + "/单次_KFold_2023.pkl")
grading_factor = pd.concat([grading_factor2023, grading_factor], axis=0)
grading_factor.to_feather("/home/datamake134/data/haris/DL/" + main_folder_name + "/单次_KFold_0.fea")
