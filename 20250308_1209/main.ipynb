# %%
import os
import random
import gc
import pandas as pd
import numpy as np
from dateutil.relativedelta import relativedelta
from tqdm.notebook import tqdm, trange
import torch
import torch.multiprocessing as mp
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler

from methods.model import *
from methods.logger import *
from methods.processing import *
from methods.train import *

# %% [markdown]
# # 读取数据

# %%
mp.set_start_method('spawn', force=True)
main_device_name = 0
print('Read Factor.')
factor = pd.read_pickle('/home/datamake117/data/haris/dataset_1209/total_date.pkl')                      # 日期+股票代码
grouped = pd.read_pickle('/home/datamake117/data/haris/dataset_1209/grouped_adj.pkl').fillna(0)          # 特征
grouped_label = pd.read_pickle('/home/datamake117/data/haris/dataset_1209/grouped_label_adj.pkl')        # 标签
grouped_liquidity = pd.read_pickle('/home/datamake117/data/haris/dataset_1209/grouped_liquidity.pkl')    # 流动性指标
grouped_liquidity.index = grouped_liquidity.index.strftime('%Y%m%d').astype(int)
correlation_df = pd.read_pickle('/home/datamake117/data/haris/dataset_1209/corr_byday_abs.pkl')          # 因子筛选辅助数据
correlation_df.index = correlation_df.index.strftime('%Y%m%d').astype(int)
total_date_list = np.array(factor['date'].drop_duplicates().tolist())                               # 日期列表
# Out:
# Read Factor.

# %%
def main(
    round_num, dt1, dt2, dt3, dt4, dt5,
    correlation_df, grouped, grouped_label, grouped_liquidity,
    total_date_list, main_folder_name, 
    pid_num=5256, factor_num=2221, corr_thres=0.9, seed_num=5, model_mode=False, multi_model=6
    ):
    '''
    para round_num: 轮数（周期序号）
    para dt1: 训练集开始时间
    para dt2: 验证集开始时间
    para dt3: 验证集结束时间
    para dt4: 测试集开始时间
    para dt5: 测试集结束时间
    
    dt1 ------训练集------ dt2 ------验证集------ dt3/dt4 ------测试集------ dt5
    
    para correlation_df: 因子筛选辅助数据
    para grouped: 按日期分组的因子数据
    para grouped_label: 按日期分组的标签数据
    para grouped_liquidity: 按日期分组的流动性数据
    para total_date_list: 全部日期
    para main_folder_name: 主文件夹名称
    para pid_num: 股票数量
    para factor_num: 因子数量
    para corr_thres: 因子筛选相关系数阈值
    para seed_num: 每个模型的种子数
    para model_mode: 是否继续训练
    para multi_model: 模型数量
    '''
    seed_list = []
    for i in range(seed_num):
        random.seed(i)
        seed_list.append(list(random.sample(range(100), multi_model)))
    total_train_num = len(seed_list)  # seed_num * multi_model
    total_test_output = []
    total_test_name = 'test_output_' + str(round_num) + '.pt'
    total_date_pid_name = 'test_date_pid_' + str(round_num) + '.pt'
    save_path = "/home/datamake117/data/haris/DL/" + main_folder_name
    
    # 根据给定的时间范围 dt1 到 dt3，选出训练集的日期列表。之后，有一个特别的日期范围处理（过滤掉指定日期段的训练数据）。
    date_list_train = total_date_list[np.where((total_date_list >= dt1) & (total_date_list < dt3))[0]]
    # 若20240223在训练周期或测试周期内，训练周期或测试周期去除20240201-20240223这一时间段
    if 20240223 >= dt1 and 20240223 <= dt3:
        date_list_train = np.array([date_train for date_train in date_list_train if date_train < 20240201 or date_train > 20240223])
    total_ts_train_val1 = np.zeros((len(date_list_train), pid_num, factor_num)) # 因子数据 shape: (len(date_list_train), pid_num, factor_num)
    total_label_train_val = np.zeros((len(date_list_train), pid_num, 5))        # 标签数据 shape: (len(date_list_train), pid_num, 5)
    total_group_train_val = np.zeros((len(date_list_train), pid_num, 1))        # 流动性数据 shape: (len(date_list_train), pid_num, 1)
    for i in trange(len(date_list_train), desc='train_val_data'):
        date = date_list_train[i]
        total_ts_train_val1[i, :, :] = grouped.loc[date].iloc[:pid_num, :]          # 因子
        total_label_train_val[i, :, :] = grouped_label.loc[date].iloc[:pid_num, :]  # 标签
        # 根据流动性调整收益率前7%-10%附近的训练标签：label(returns)
        total_label_train_val[i, :, 0] = adjust_daily_returns(total_label_train_val[i, :, 0], total_label_train_val[i, :, 4])
        total_group_train_val[i, :, :] = np.array(grouped_liquidity.loc[date])[:pid_num].reshape(-1, 1)  # 流动性
    
    # 类似地，date_list_test 被定义为测试集的日期范围，时间从 dt4 到 dt5。
    date_list_test = total_date_list[np.where((total_date_list >= dt4) & (total_date_list < dt5))[0]]
    total_ts_test1 = np.zeros((len(date_list_test), pid_num, factor_num))
    total_label_test = np.zeros((len(date_list_test), pid_num, 5))
    total_group_test = np.zeros((len(date_list_test), pid_num, 1))
    for i in trange(len(date_list_test), desc='test_data'):
        date = date_list_test[i]
        total_ts_test1[i, :, :] = grouped.loc[date].iloc[:pid_num, :]
        total_label_test[i, :, :] = grouped_label.loc[date].iloc[:pid_num, :]
        total_label_test[i, :, 0] = adjust_daily_returns(total_label_test[i, :, 0], total_label_test[i, :, 4])
        total_group_test[i, :, :] = np.array(grouped_liquidity.loc[date])[:pid_num].reshape(-1, 1)
    
    # 流动性数据归一化
    def min_max_standard(column):
        return (column - column.min()) / (column.max() - column.min())
    print('Min-max scaling.')
    total_group_train_val, total_group_test = min_max_standard(total_group_train_val), min_max_standard(total_group_test)
    
    # 因子数据标准化
    print('Standard scaling.')
    scaler = StandardScaler()
    total_ts_train_val1 = np.apply_along_axis(
        lambda x: np.clip(x, np.percentile(x, 0.5), np.percentile(x, 99.5)), axis=0, arr=total_ts_train_val1.reshape(-1, factor_num)
        )  # 去极值，保留0.5%-99.5%数据
    total_ts_train_val1 = total_ts_train_val1.reshape(len(date_list_train), pid_num, factor_num)
    total_ts_train_val1 = np.nan_to_num(scaler.fit_transform(total_ts_train_val1.reshape(-1, factor_num)).reshape(len(date_list_train), pid_num, factor_num), nan=0)
    total_ts_test1 = np.apply_along_axis(
        lambda x: np.clip(x, np.percentile(x, 0.5), np.percentile(x, 99.5)), axis=0, arr=total_ts_test1.reshape(-1, factor_num)
        )
    total_ts_test1 = total_ts_test1.reshape(len(date_list_test), pid_num, factor_num)
    total_ts_test1 = np.nan_to_num(scaler.transform(total_ts_test1.reshape(-1, factor_num)).reshape(len(date_list_test), pid_num, factor_num), nan=0)
    
    # KFold 交叉验证（并行训练）
    print('KFold training.')
    kf = KFold(n_splits=total_train_num, shuffle=False)
    processes = []
    for train_num, index_tuple in enumerate(kf.split(total_ts_train_val1)):
        p = mp.Process(
            target=train_one_Fold, 
            args=(
                round_num, train_num, index_tuple, main_folder_name,
                total_ts_train_val1, total_label_train_val, total_group_train_val, date_list_train,
                total_ts_test1, total_label_test, total_group_test, date_list_test,
                correlation_df, seed_list, dt1, dt2, dt3, dt4, dt5,
                factor_num, corr_thres, save_path, model_mode, multi_model
                )
            )
        processes.append(p)
        p.start()
    for p in processes:
        p.join()
    
    torch.cuda.empty_cache()
    gc.collect()
    
    # 保存测试数据
    print('Save test data.')
    total_test_output = []
    for train_num in range(total_train_num):
        test_name = 'test_output_ic' + str(round_num) + str(train_num) + '.pt'
        test_path = os.path.join(save_path, test_name)
        total_test_output.append(torch.load(test_path))
        
    total_test_path = os.path.join(save_path, total_test_name)
    total_date_pid_path = os.path.join(save_path, total_date_pid_name)
    
    total_test_output = torch.stack(total_test_output)
    weight_tensor = torch.tensor([0.1, 0.15, 0.2, 0.25, 0.3]).view(-1, *([1] * (total_test_output.dim() - 1)))
    total_test_output = (total_test_output * weight_tensor).sum(dim=0)
    torch.save(total_test_output, total_test_path)
    
    stocks = np.array(grouped_label.loc[20200102].index)
    repeated_stocks = np.tile(stocks, len(date_list_test))
    repeated_dates = np.repeat(date_list_test, len(stocks))
    date_pid_test = np.column_stack((repeated_dates, repeated_stocks))
    torch.save(date_pid_test, total_date_pid_path)
    
    del total_ts_train_val1
    del total_ts_test1
    del total_label_train_val
    del total_label_test
    del total_group_train_val
    del total_group_test
    
    torch.cuda.empty_cache()
    gc.collect()

# %% [markdown]
# # 训练和测试
#
# ```c
# Round 1. Train: 2020/07/01 2022/07/01 Validation: 2022/07/01 2022/12/30 Test: 2023/01/01 2023/07/01
# Round 2. Train: 2021/01/01 2023/01/01 Validation: 2023/01/01 2023/03/31 Test: 2023/04/01 2023/07/01
# Round 3. Train: 2021/04/01 2023/04/01 Validation: 2023/04/01 2023/06/30 Test: 2023/07/01 2023/10/01
# Round 4. Train: 2021/07/01 2023/07/01 Validation: 2023/07/01 2023/09/28 Test: 2023/10/01 2024/01/01
# Round 5. Train: 2021/10/01 2023/10/01 Validation: 2023/10/01 2023/12/29 Test: 2024/01/01 2024/04/01
# Round 6. Train: 2022/01/01 2024/01/01 Validation: 2024/01/01 2024/03/29 Test: 2024/04/01 2024/07/01
# Round 7. Train: 2022/04/01 2024/04/01 Validation: 2024/04/01 2024/06/28 Test: 2024/07/01 2024/10/01
# Round 8. Train: 2022/07/01 2024/07/01 Validation: 2024/07/01 2024/09/30 Test: 2024/10/01 2025/01/01
# Round 9. Train: 2022/10/01 2024/10/01 Validation: 2024/10/01 2024/12/31 Test: 2025/01/01 2025/02/21
# ```

# %%
folder_path = "/home/datamake117/data/haris/DL/" + main_folder_name
os.makedirs(folder_path, exist_ok=True)

# 第1轮
print('Round 1.')
round_num = 1
dt1 = int(pd.to_datetime("2020-07-01").strftime('%Y%m%d'))  # 训练集开始时间
dt2 = int(pd.to_datetime("2022-07-01").strftime('%Y%m%d'))  # 验证集开始时间
dt3 = int(pd.to_datetime("2022-12-30").strftime('%Y%m%d'))  # 验证集结束时间
dt4 = int(pd.to_datetime("2023-01-01").strftime('%Y%m%d'))  # 测试集开始时间
dt5 = int(pd.to_datetime("2023-04-01").strftime('%Y%m%d'))  # 测试集结束时间
main(
    round_num, dt1, dt2, dt3, dt4, dt5,
    correlation_df, grouped, grouped_label, grouped_liquidity,
    total_date_list, main_folder_name, corr_thres=0.9
    )
torch.cuda.empty_cache()
gc.collect()

test_output1 = torch.load("/home/datamake117/data/haris/DL/" + main_folder_name + "/test_output_1.pt")
test_output = torch.cat([test_output1])
test_output = test_output.cpu()
date_pid1 = torch.load("/home/datamake117/data/haris/DL/" + main_folder_name + "/test_date_pid_1.pt", weights_only=False)
total_date_pid = np.concatenate([date_pid1], axis=0)
total_date_pid_test = total_date_pid
grading_factor = pd.DataFrame(index=np.unique(total_date_pid_test[:, 0]), columns=np.unique(total_date_pid_test[:, 1]))
test_output_list = test_output.tolist()
for i in range(len(total_date_pid_test)):
    grading_factor.loc[total_date_pid_test[i][0], total_date_pid_test[i][1]] = test_output_list[i]
grading_factor.to_pickle("/home/datamake117/data/haris/DL/" + main_folder_name + "/单次_KFold_2023.pkl")
gc.collect()
# Out:
# Round 1.
# train_val_data:   0%|          | 0/610 [00:00<?, ?it/s]
# test_data:   0%|          | 0/59 [00:00<?, ?it/s]
# Min-max scaling.
# Standard scaling.
# KFold training.
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2025/03/07 21:46:25 train.py INFO Period2, Train2, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230401
# 2025/03/07 21:46:25 train.py INFO Train1 Shape: torch.Size([305, 5256, 2221]), Val1 Shape: torch.Size([304, 5256, 2221]), Test1 Shape: torch.Size([59, 5256, 2221])
# 2025/03/07 21:46:25 train.py INFO Start Training
# 2025/03/07 21:48:13 train.py INFO Epoch[1/200], Time:108.09sec, Train Loss: nan, Val Loss: 0.8859518766403198,0.8842823505401611,nan,0.8847836256027222,0.8835442066192627,nan
# 2025/03/07 21:48:13 model.py INFO Validation loss decreased (inf --> 0.885952).  Saving model 0.0...
# 2025/03/07 21:48:13 model.py INFO Validation loss decreased (inf --> 0.884282).  Saving model 1.0...
# 2025/03/07 21:48:13 model.py INFO Validation loss decreased (inf --> nan).  Saving model 2.0...
# 2025/03/07 21:48:13 model.py INFO Validation loss decreased (inf --> 0.884784).  Saving model 3.0...
# 2025/03/07 21:48:13 model.py INFO Validation loss decreased (inf --> 0.883544).  Saving model 4.0...
# 2025/03/07 21:48:13 model.py INFO Validation loss decreased (inf --> nan).  Saving model 5.0...
# 2025/03/07 21:50:02 train.py INFO Epoch[2/200], Time:108.64sec, Train Loss: nan, Val Loss: 0.8707319498062134,0.8779604434967041,nan,0.8761231899261475,0.8746305704116821,nan
# 2025/03/07 21:50:02 model.py INFO Validation loss decreased (0.885952 --> 0.870732).  Saving model 0.0...
# 2025/03/07 21:50:02 model.py INFO Validation loss decreased (0.884282 --> 0.877960).  Saving model 1.0...
# 2025/03/07 21:50:02 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/07 21:50:02 model.py INFO Validation loss decreased (0.884784 --> 0.876123).  Saving model 3.0...
# 2025/03/07 21:50:02 model.py INFO Validation loss decreased (0.883544 --> 0.874631).  Saving model 4.0...
# 2025/03/07 21:50:02 model.py INFO EarlyStopping counter: 1 out of 10
# /home/datamake117/.local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2025/03/07 21:50:51 train.py INFO Period2, Train2, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230401
# 2025/03/07 21:50:51 train.py INFO Train1 Shape: torch.Size([305, 5256, 2221]), Val1 Shape: torch.Size([304, 5256, 2221]), Test1 Shape: torch.Size([59, 5256, 2221])
# 2025/03/07 21:50:51 train.py INFO Start Training
# 2025/03/07 21:52:04 train.py INFO Epoch[3/200], Time:121.73sec, Train Loss: nan, Val Loss: 0.8673845529556274,0.8736611604690552,nan,0.8723633885383606,0.8747986555099487,nan
# 2025/03/07 21:52:04 model.py INFO Validation loss decreased (0.870732 --> 0.867385).  Saving model 0.0...
# 2025/03/07 21:52:04 model.py INFO Validation loss decreased (0.877960 --> 0.873661).  Saving model 1.0...
# 2025/03/07 21:52:04 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/07 21:52:04 model.py INFO Validation loss decreased (0.876123 --> 0.872363).  Saving model 3.0...
# 2025/03/07 21:52:04 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/07 21:52:04 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/07 21:52:57 train.py INFO Epoch[1/200], Time:125.87sec, Train Loss: nan, Val Loss: nan,0.8954070210456848,0.8928878307342529,nan,0.8912560343742371,0.8961278796195984
# 2025/03/07 21:52:57 model.py INFO Validation loss decreased (inf --> nan).  Saving model 0.0...
# 2025/03/07 21:52:57 model.py INFO Validation loss decreased (inf --> 0.895407).  Saving model 1.0...
# 2025/03/07 21:52:57 model.py INFO Validation loss decreased (inf --> 0.892888).  Saving model 2.0...
# 2025/03/07 21:52:57 model.py INFO Validation loss decreased (inf --> nan).  Saving model 3.0...
# 2025/03/07 21:52:57 model.py INFO Validation loss decreased (inf --> 0.891256).  Saving model 4.0...
# 2025/03/07 21:52:57 model.py INFO Validation loss decreased (inf --> 0.896128).  Saving model 5.0...
# 2025/03/07 21:54:07 train.py INFO Epoch[4/200], Time:123.59sec, Train Loss: nan, Val Loss: 0.8675196170806885,0.8761054277420044,nan,0.8698021769523621,0.8725696802139282,nan
# 2025/03/07 21:54:07 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/07 21:54:07 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/07 21:54:07 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/07 21:54:07 model.py INFO Validation loss decreased (0.872363 --> 0.869802).  Saving model 3.0...
# 2025/03/07 21:54:08 model.py INFO Validation loss decreased (0.874631 --> 0.872570).  Saving model 4.0...
# 2025/03/07 21:54:08 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/07 21:55:02 train.py INFO Epoch[2/200], Time:124.89sec, Train Loss: nan, Val Loss: nan,0.8819918632507324,0.8911558389663696,nan,0.8863925337791443,0.8926331400871277
# 2025/03/07 21:55:02 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/07 21:55:02 model.py INFO Validation loss decreased (0.895407 --> 0.881992).  Saving model 1.0...
# 2025/03/07 21:55:02 model.py INFO Validation loss decreased (0.892888 --> 0.891156).  Saving model 2.0...
# 2025/03/07 21:55:02 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/07 21:55:02 model.py INFO Validation loss decreased (0.891256 --> 0.886393).  Saving model 4.0...
# 2025/03/07 21:55:02 model.py INFO Validation loss decreased (0.896128 --> 0.892633).  Saving model 5.0...
# 2025/03/07 21:56:07 train.py INFO Epoch[5/200], Time:119.95sec, Train Loss: nan, Val Loss: 0.8723714351654053,0.8787960410118103,nan,0.8699638247489929,0.8716510534286499,nan
# 2025/03/07 21:56:07 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/07 21:56:07 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/07 21:56:07 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/07 21:56:07 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/07 21:56:07 model.py INFO Validation loss decreased (0.872570 --> 0.871651).  Saving model 4.0...
# 2025/03/07 21:56:08 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/07 21:57:09 train.py INFO Epoch[3/200], Time:127.37sec, Train Loss: nan, Val Loss: nan,0.8845041394233704,0.8896321058273315,nan,0.8838400840759277,0.8916034698486328
# 2025/03/07 21:57:09 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/07 21:57:09 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/07 21:57:09 model.py INFO Validation loss decreased (0.891156 --> 0.889632).  Saving model 2.0...
# 2025/03/07 21:57:09 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/07 21:57:09 model.py INFO Validation loss decreased (0.886393 --> 0.883840).  Saving model 4.0...
# 2025/03/07 21:57:09 model.py INFO Validation loss decreased (0.892633 --> 0.891603).  Saving model 5.0...
# 2025/03/07 21:58:16 train.py INFO Epoch[6/200], Time:128.27sec, Train Loss: nan, Val Loss: 0.8763852119445801,0.8829253911972046,nan,0.8700920343399048,0.8725314140319824,nan
# 2025/03/07 21:58:16 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/07 21:58:16 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/07 21:58:16 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/07 21:58:16 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/07 21:58:16 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/07 21:58:16 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/07 21:59:16 train.py INFO Epoch[4/200], Time:126.81sec, Train Loss: nan, Val Loss: nan,0.882513165473938,0.8948970437049866,nan,0.8809419870376587,0.8939317464828491
# 2025/03/07 21:59:16 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/07 21:59:16 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/07 21:59:16 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/07 21:59:16 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/07 21:59:16 model.py INFO Validation loss decreased (0.883840 --> 0.880942).  Saving model 4.0...
# 2025/03/07 21:59:16 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/07 22:00:22 train.py INFO Epoch[7/200], Time:125.74sec, Train Loss: nan, Val Loss: 0.879570484161377,0.885580837726593,nan,0.8742753863334656,0.8753880858421326,nan
# 2025/03/07 22:00:22 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/07 22:00:22 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/07 22:00:22 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/03/07 22:00:22 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/07 22:00:22 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/07 22:00:22 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/03/07 22:01:21 train.py INFO Epoch[5/200], Time:124.99sec, Train Loss: nan, Val Loss: nan,0.8824450373649597,0.8959526419639587,nan,0.8757896423339844,0.8952652215957642
# 2025/03/07 22:01:21 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/07 22:01:21 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/07 22:01:21 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/07 22:01:21 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/07 22:01:21 model.py INFO Validation loss decreased (0.880942 --> 0.875790).  Saving model 4.0...
# 2025/03/07 22:01:21 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/07 22:02:26 train.py INFO Epoch[8/200], Time:124.52sec, Train Loss: nan, Val Loss: 0.8811073899269104,0.8881262540817261,nan,0.8790742754936218,0.876041829586029,nan
# 2025/03/07 22:02:26 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/07 22:02:26 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/07 22:02:26 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/03/07 22:02:26 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/07 22:02:26 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/07 22:02:26 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/03/07 22:03:21 train.py INFO Epoch[6/200], Time:120.28sec, Train Loss: nan, Val Loss: nan,0.8842448592185974,0.898933470249176,nan,0.8805125951766968,0.8940209746360779
# 2025/03/07 22:03:21 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/07 22:03:21 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/07 22:03:21 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/07 22:03:21 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/07 22:03:21 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/03/07 22:03:21 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/07 22:04:27 train.py INFO Epoch[9/200], Time:120.49sec, Train Loss: nan, Val Loss: 0.885096549987793,0.8982937335968018,nan,0.8859615325927734,0.8827153444290161,nan
# 2025/03/07 22:04:27 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/03/07 22:04:27 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/03/07 22:04:27 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/03/07 22:04:27 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/07 22:04:27 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/07 22:04:27 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/03/07 22:05:24 train.py INFO Epoch[7/200], Time:122.52sec, Train Loss: nan, Val Loss: nan,0.8921413421630859,0.9007370471954346,nan,0.8866453766822815,0.8975926041603088
# 2025/03/07 22:05:24 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/03/07 22:05:24 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/07 22:05:24 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/07 22:05:24 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/03/07 22:05:24 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/03/07 22:05:24 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/07 22:06:30 train.py INFO Epoch[10/200], Time:123.46sec, Train Loss: nan, Val Loss: 0.890241801738739,0.9027807712554932,nan,0.8878190517425537,0.8858722448348999,nan
# 2025/03/07 22:06:30 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/03/07 22:06:30 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/03/07 22:06:30 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/03/07 22:06:30 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/03/07 22:06:30 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/07 22:06:30 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/03/07 22:07:27 train.py INFO Epoch[8/200], Time:123.17sec, Train Loss: nan, Val Loss: nan,0.8953422904014587,0.9020934104919434,nan,0.8905280828475952,0.9024625420570374
# 2025/03/07 22:07:27 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/03/07 22:07:27 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/03/07 22:07:27 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/07 22:07:27 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/03/07 22:07:27 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/03/07 22:07:27 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/07 22:08:33 train.py INFO Epoch[11/200], Time:123.10sec, Train Loss: nan, Val Loss: 0.8941503167152405,0.9068405032157898,nan,0.8944846987724304,0.8891143202781677,nan
# 2025/03/07 22:08:33 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/03/07 22:08:33 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/03/07 22:08:33 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/03/07 22:08:33 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/03/07 22:08:33 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/03/07 22:08:33 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/03/07 22:09:30 train.py INFO Epoch[9/200], Time:122.56sec, Train Loss: nan, Val Loss: nan,0.8974316716194153,0.9060006737709045,nan,0.896728515625,0.9074944257736206
# 2025/03/07 22:09:30 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/03/07 22:09:30 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/03/07 22:09:30 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/03/07 22:09:30 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/03/07 22:09:30 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/03/07 22:09:30 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/03/07 22:10:03 train.py INFO Epoch[12/200], Time:89.53sec, Train Loss: nan, Val Loss: 0.8984857201576233,0.9135109782218933,nan,0.9026623964309692,0.8959829211235046,nan
# 2025/03/07 22:10:03 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/03/07 22:10:03 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/03/07 22:10:03 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/03/07 22:10:03 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/03/07 22:10:03 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/03/07 22:10:03 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/03/07 22:11:37 train.py INFO Epoch[10/200], Time:127.12sec, Train Loss: nan, Val Loss: nan,0.899387001991272,0.9098532795906067,nan,0.9026544690132141,0.9071745872497559
# 2025/03/07 22:11:37 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/03/07 22:11:37 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/03/07 22:11:37 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/03/07 22:11:37 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/03/07 22:11:37 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/03/07 22:11:37 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/03/07 22:11:38 train.py INFO Epoch[13/200], Time:94.97sec, Train Loss: nan, Val Loss: 0.8989143371582031,0.9149441123008728,nan,0.9024598002433777,0.8978303670883179,nan
# 2025/03/07 22:11:38 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/03/07 22:11:38 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/03/07 22:11:38 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/03/07 22:11:38 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/03/07 22:11:38 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/03/07 22:11:38 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/03/07 22:12:39 train.py INFO Epoch[14/200], Time:61.36sec, Train Loss: nan, Val Loss: 0.8989143371582031,0.9149441123008728,nan,0.9105543494224548,0.9016640186309814,nan
# 2025/03/07 22:12:39 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/03/07 22:12:39 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/03/07 22:12:39 model.py INFO EarlyStopping counter: 13 out of 10
# 2025/03/07 22:12:39 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/03/07 22:12:39 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/03/07 22:12:39 model.py INFO EarlyStopping counter: 13 out of 10
# 2025/03/07 22:13:32 train.py INFO Epoch[15/200], Time:53.21sec, Train Loss: nan, Val Loss: 0.8989143371582031,0.9149441123008728,nan,0.9105543494224548,0.9030983448028564,nan
# 2025/03/07 22:13:32 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/03/07 22:13:32 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/03/07 22:13:32 model.py INFO EarlyStopping counter: 14 out of 10
# 2025/03/07 22:13:32 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/03/07 22:13:32 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/03/07 22:13:32 model.py INFO EarlyStopping counter: 14 out of 10
# 2025/03/07 22:13:32 train.py INFO Early stopping
# 2025/03/07 22:13:32 train.py INFO Val Loss: 0.8673845529556274,0.8736611604690552,nan,0.8698021769523621,0.8716510534286499,nan
# 2025/03/07 22:13:38 train.py INFO Test Loss: 0.000000
# 2025/03/07 22:13:42 train.py INFO Finish 2 Fold.
# 2025/03/07 22:13:42 train.py INFO Epoch[11/200], Time:124.97sec, Train Loss: nan, Val Loss: nan,0.8988893628120422,0.9151615500450134,nan,0.9145964980125427,0.9121361970901489
# 2025/03/07 22:13:42 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/03/07 22:13:42 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/03/07 22:13:42 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/03/07 22:13:42 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/03/07 22:13:42 model.py INFO EarlyStopping counter: 6 out of 10
# 2025/03/07 22:13:42 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/03/07 22:14:57 train.py INFO Epoch[12/200], Time:75.44sec, Train Loss: nan, Val Loss: nan,0.9111207723617554,0.9143677949905396,nan,0.9309226870536804,0.9135469198226929
# 2025/03/07 22:14:57 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/03/07 22:14:57 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/03/07 22:14:57 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/03/07 22:14:57 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/03/07 22:14:57 model.py INFO EarlyStopping counter: 7 out of 10
# 2025/03/07 22:14:57 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/03/07 22:15:57 train.py INFO Epoch[13/200], Time:59.80sec, Train Loss: nan, Val Loss: nan,0.9111207723617554,0.918298602104187,nan,0.9245637655258179,0.9186468720436096
# 2025/03/07 22:15:57 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/03/07 22:15:57 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/03/07 22:15:57 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/03/07 22:15:57 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/03/07 22:15:57 model.py INFO EarlyStopping counter: 8 out of 10
# 2025/03/07 22:15:57 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/03/07 22:16:31 train.py INFO Epoch[14/200], Time:33.89sec, Train Loss: nan, Val Loss: nan,0.9111207723617554,0.918298602104187,nan,0.9191616773605347,0.9186468720436096
# 2025/03/07 22:16:31 model.py INFO EarlyStopping counter: 13 out of 10
# 2025/03/07 22:16:31 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/03/07 22:16:31 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/03/07 22:16:31 model.py INFO EarlyStopping counter: 13 out of 10
# 2025/03/07 22:16:31 model.py INFO EarlyStopping counter: 9 out of 10
# 2025/03/07 22:16:31 model.py INFO EarlyStopping counter: 11 out of 10
# 2025/03/07 22:17:05 train.py INFO Epoch[15/200], Time:34.46sec, Train Loss: nan, Val Loss: nan,0.9111207723617554,0.918298602104187,nan,0.9248648881912231,0.9186468720436096
# 2025/03/07 22:17:05 model.py INFO EarlyStopping counter: 14 out of 10
# 2025/03/07 22:17:05 model.py INFO EarlyStopping counter: 13 out of 10
# 2025/03/07 22:17:05 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/03/07 22:17:05 model.py INFO EarlyStopping counter: 14 out of 10
# 2025/03/07 22:17:05 model.py INFO EarlyStopping counter: 10 out of 10
# 2025/03/07 22:17:05 model.py INFO EarlyStopping counter: 12 out of 10
# 2025/03/07 22:17:05 train.py INFO Early stopping
# 2025/03/07 22:17:05 train.py INFO Val Loss: nan,0.8819918632507324,0.8896321058273315,nan,0.8757896423339844,0.8916034698486328
# 2025/03/07 22:17:10 train.py INFO Test Loss: 0.000000
# 2025/03/07 22:17:13 train.py INFO Finish 2 Fold.
# Save test data.
# /tmp/ipykernel_2522566/3225535006.py:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   total_test_output.append(torch.load(test_path))
# /tmp/ipykernel_2522566/1015944235.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_output1 = torch.load("/home/datamake117/data/haris/DL/" + main_folder_name + "/test_output_1.pt")
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 29
#      27 test_output_list = test_output.tolist()
#      28 for i in range(len(total_date_pid_test)):
# ---> 29     grading_factor.loc[total_date_pid_test[i][0], total_date_pid_test[i][1]] = test_output_list[i]
#      30 grading_factor.to_pickle("/home/datamake117/data/haris/DL/" + main_folder_name + "/单次_KFold_2023.pkl")
#      31 gc.collect()
#
# IndexError: list index out of range

# %%
len(test_output), len(total_date_pid_test)
# Out:
# (310045, 310104)

# %%
# 第2-9轮
total_date_list = np.array(factor['date'].drop_duplicates().tolist())
rolling_step = 3    # 3个月滚动训练
window_size = 24    # 训练集大小
val_size = 3        # 验证集大小
corr_thres = 0.9
for round_num in range(2, 10):
    print('Round %i.' % round_num)
    start_date = pd.to_datetime('2021-01-01')
    dt1 = start_date + relativedelta(months=rolling_step * (round_num - 2))             # 训练集开始时间
    dt2 = dt1 + relativedelta(months=window_size)                                       # 验证集开始时间
    dt3 = dt2 + relativedelta(months=val_size)                                          # 验证集结束时间
    dt4 = dt3                                                                           # 测试集开始时间
    dt5 = min(dt3 + relativedelta(months=rolling_step), pd.to_datetime('2025-02-21'))   # 测试集结束时间
    dt3 = total_date_list[total_date_list < int(dt3.strftime('%Y%m%d'))][-1]
    dt1, dt2, dt3, dt4, dt5 = int(dt1.strftime('%Y%m%d')), int(dt2.strftime('%Y%m%d')), int(dt3), int(dt4.strftime('%Y%m%d')), int(dt5.strftime('%Y%m%d'))
    main(
        round_num, dt1, dt2, dt3, dt4, dt5,
        correlation_df, grouped, grouped_label, grouped_liquidity,
        total_date_list, main_folder_name, corr_thres=0.9, seed_num=5, model_mode=False
        )
    torch.cuda.empty_cache()
    gc.collect()

test_output_list = []
for round_num in range(2, 10):
    test_output = torch.load("/home/datamake117/data/haris/DL/" + main_folder_name + "/test_output_" + str(round_num) + ".pt")
    test_output_list.append(test_output)
test_output = torch.cat(test_output_list)
test_output = test_output.cpu()
date_pid_list = []
for round_num in range(2, 10):
    date_pid = torch.load("/home/datamake117/data/haris/DL/" + main_folder_name + "/test_date_pid_" + str(round_num) + ".pt", weights_only=False)
    date_pid_list.append(date_pid)
total_date_pid = np.concatenate(date_pid_list, axis=0)
total_date_pid_test = total_date_pid
grading_factor = pd.DataFrame(index=np.unique(total_date_pid_test[:, 0]), columns=np.unique(total_date_pid_test[:, 1]))
test_output_list = test_output.tolist()
for i in range(len(total_date_pid_test)):
    grading_factor.loc[total_date_pid_test[i][0], total_date_pid_test[i][1]] = test_output_list[i]
grading_factor2023 = pd.read_pickle("/home/datamake117/data/haris/DL/" + main_folder_name + "/单次_KFold_2023.pkl")
grading_factor = pd.concat([grading_factor2023, grading_factor], axis=0)
grading_factor.to_feather("/home/datamake117/data/haris/DL/" + main_folder_name + "/单次_KFold_0.fea")
