# %%
import os
import random
import gc
import pandas as pd
import numpy as np
from dateutil.relativedelta import relativedelta
from tqdm.notebook import tqdm, trange
import torch
import torch.multiprocessing as mp
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler

from methods.model import *
from methods.logger import *
from methods.processing import *
from methods.train import *

# %% [markdown]
# # 读取数据

# %%
mp.set_start_method('spawn', force=True)
main_device_name = 0
print('Read Factor.')
factor = pd.read_pickle('/home/datamake134/data/haris/dataset/total_date.pkl')                      # 日期+股票代码
grouped = pd.read_pickle('/home/datamake134/data/haris/dataset/grouped_adj.pkl').fillna(0)          # 特征
grouped_label = pd.read_pickle('/home/datamake134/data/haris/dataset/grouped_label_adj.pkl')        # 标签
grouped_liquidity = pd.read_pickle('/home/datamake134/data/haris/dataset/grouped_liquidity.pkl')    # 流动性指标
grouped_liquidity.index = grouped_liquidity.index.strftime('%Y%m%d').astype(int)
correlation_df = pd.read_pickle('/home/datamake134/data/haris/dataset/corr_byday_abs.pkl')          # 因子筛选辅助数据
# correlation_df.index = correlation_df.index.strftime('%Y%m%d').astype(int)
total_date_list = np.array(factor['date'].drop_duplicates().tolist())                               # 日期列表
# Out:
# Read Factor.

# %%
import numpy as np


# 根据流动性调整收益率前7%-10%附近的训练标签，给的默认参数应该就是之前测试的效果比较好的
def adjust_daily_returns(returns, liquidity, threshold=0.01, lower_percentile=0.90, upper_percentile=0.95):
    """
    思路：收益率接近的一组股票按照流动性从高到低重新分配调整后的收益率。
    根据流动性调整收益率，但仅针对真实收益率处于指定分位数范围内的部分。
    :param returns: 单天的原始收益率标签 (1D NumPy 数组)，可能含 NaN。
    :param liquidity: 单天的流动性指标 (1D NumPy 数组)，可能含 NaN。
    :param threshold: 收益率分组的阈值 (同组内收益率差值最大为 threshold)。
    :param lower_percentile: 分位数的下界 (默认 90%)。
    :param upper_percentile: 分位数的上界 (默认 93%)。
    :return: 调整后的收益率标签 (1D NumPy 数组)，NaN 保留在原位。
    """
    # Step 0: 筛选非 NaN 数据
    valid_mask = ~np.isnan(returns) & ~np.isnan(liquidity)  # 同时非 NaN
    valid_returns = returns[valid_mask]
    valid_liquidity = liquidity[valid_mask]
    if len(valid_returns) == 0:  # 如果有效数据不足，直接返回原数组（保持原始 NaN 结构）
        return returns

    # Step 1: 计算分位数范围
    lower_bound = np.percentile(valid_returns, lower_percentile * 100)
    upper_bound = np.percentile(valid_returns, upper_percentile * 100)

    # Step 2: 筛选处于分位数范围内的收益率
    in_range_mask = (valid_returns >= lower_bound) & (valid_returns <= upper_bound)
    if not np.any(in_range_mask):  # 如果分位数范围内没有数据，则直接返回原数组
        print(1)
        return returns
    in_range_indices = np.where(in_range_mask)[0]
    in_range_returns = valid_returns[in_range_mask]
    in_range_liquidity = valid_liquidity[in_range_mask]

    # Step 3: 按收益率排序并分组
    sorted_indices = np.argsort(in_range_returns)
    sorted_returns = in_range_returns[sorted_indices]
    sorted_liquidity = in_range_liquidity[sorted_indices]
    diff = np.diff(sorted_returns)
    group_indices = np.where(diff > threshold)[0] + 1  # 找到分组边界
    groups = np.split(np.arange(len(sorted_returns)), group_indices)  # 分组索引

    # Step 4: 调整每组的收益率（每组内在[r_min, r_max]区间内线性插值，按照流动性大小排序）
    # adjusted_returns = np.zeros_like(in_range_returns)
    # for group in groups:
    #     group_returns = sorted_returns[group]
    #     group_liquidity = sorted_liquidity[group]
    #     mu = group_returns.mean()
    #     sigma = group_returns.std()
    #     if sigma == 0:  # 避免除0
    #         sigma = 1e-6
    #     liquidity_sorted_indices = np.argsort(-group_liquidity)  # 按流动性降序排序
    #     liquidity_scores = group_liquidity[liquidity_sorted_indices]  # 构造 softmax 权重
    #     weights = np.exp(liquidity_scores)
    #     weights /= (np.sum(weights) + 1e-10)
    #     # 将 softmax 权重映射到 z 分数（标准正态排序值）
    #     from scipy.stats import norm
    #     ranks = np.cumsum(weights) - 0.5 * weights  # 类似 rank 的值
    #     z_scores = norm.ppf(ranks)  # 转换为标准正态分布值
    #     z_scores = (z_scores - np.min(z_scores)) / (np.max(z_scores) - np.min(z_scores) + 1e-10)  # 归一化到 [0,1]
    #     adjusted_group_returns = mu + sigma * z_scores  # 非线性调整后的收益率
    #     adjusted_returns[group[liquidity_sorted_indices]] = adjusted_group_returns
    adjusted_returns = np.zeros_like(in_range_returns)
    for group in groups:
        group_returns = sorted_returns[group]
        group_liquidity = sorted_liquidity[group]
        r_min, r_max = group_returns.min(), group_returns.max()  # 计算组内的最小和最大收益率
        liquidity_sorted_indices = np.argsort(-group_liquidity)  # 按流动性降序排序，并计算 rank
        ranks = np.linspace(0, 1, len(group_liquidity))
        adjusted_group_returns = r_min + (r_max - r_min) * (1 - ranks)  # 按 rank 线性插值调整收益率
        adjusted_returns[group[liquidity_sorted_indices]] = adjusted_group_returns  # 将调整后的收益率映射回对应位置

    # Step 5: 将调整后的部分还原到原始索引中
    final_adjusted_returns = returns.copy()
    final_adjusted_returns[valid_mask] = valid_returns  # 初始化为原值 
    global_indices = np.where(valid_mask)[0][in_range_indices]  # 找到在 returns 原始数组中的真实位置
    final_adjusted_returns[global_indices] = adjusted_returns  # 覆盖调整部分
    
    # print(returns[valid_mask][in_range_indices][:10])
    # print(adjusted_returns[:10])
    # print(final_adjusted_returns[valid_mask][in_range_indices][:10])

    return final_adjusted_returns

# %%
def main(
    round_num, dt1, dt2, dt3, dt4, dt5,
    correlation_df, grouped, grouped_label, grouped_liquidity,
    total_date_list, main_folder_name, 
    pid_num=5255, factor_num=2790, corr_thres=0.9, seed_num=5, model_mode=False, multi_model=6
    ):
    '''
    para round_num: 轮数（周期序号）
    para dt1: 训练集开始时间
    para dt2: 验证集开始时间
    para dt3: 验证集结束时间
    para dt4: 测试集开始时间
    para dt5: 测试集结束时间
    
    dt1 ------训练集------ dt2 ------验证集------ dt3/dt4 ------测试集------ dt5
    
    para correlation_df: 因子筛选辅助数据
    para grouped: 按日期分组的因子数据
    para grouped_label: 按日期分组的标签数据
    para grouped_liquidity: 按日期分组的流动性数据
    para total_date_list: 全部日期
    para main_folder_name: 主文件夹名称
    para pid_num: 股票数量
    para factor_num: 因子数量
    para corr_thres: 因子筛选相关系数阈值
    para seed_num: 每个模型的种子数
    para model_mode: 是否继续训练
    para multi_model: 模型数量
    '''
    seed_list = []
    for i in range(seed_num):
        random.seed(i)
        seed_list.append(list(random.sample(range(100), multi_model)))
    total_train_num = len(seed_list)  # seed_num * multi_model
    total_test_output = []
    total_test_name = 'test_output_' + str(round_num) + '.pt'
    total_date_pid_name = 'test_date_pid_' + str(round_num) + '.pt'
    save_path = "/home/datamake134/data/haris/DL/" + main_folder_name
    
    # 根据给定的时间范围 dt1 到 dt3，选出训练集的日期列表。之后，有一个特别的日期范围处理（过滤掉指定日期段的训练数据）。
    date_list_train = total_date_list[np.where((total_date_list >= dt1) & (total_date_list < dt3))[0]]
    # 若20240223在训练周期或测试周期内，训练周期或测试周期去除20240201-20240223这一时间段
    if 20240223 >= dt1 and 20240223 <= dt3:
        date_list_train = np.array([date_train for date_train in date_list_train if date_train < 20240201 or date_train > 20240223])
    total_ts_train_val1 = np.zeros((len(date_list_train), pid_num, factor_num)) # 因子数据 shape: (len(date_list_train), pid_num, factor_num)
    total_label_train_val = np.zeros((len(date_list_train), pid_num, 5))        # 标签数据 shape: (len(date_list_train), pid_num, 5)
    total_group_train_val = np.zeros((len(date_list_train), pid_num, 1))        # 流动性数据 shape: (len(date_list_train), pid_num, 1)
    for i in trange(len(date_list_train), desc='train_val_data'):
        date = date_list_train[i]
        total_ts_train_val1[i, :, :] = grouped.loc[date].iloc[:pid_num, :]          # 因子
        total_label_train_val[i, :, :] = grouped_label.loc[date].iloc[:pid_num, :]  # 标签
        # 根据流动性调整收益率前7%-10%附近的训练标签：label(returns)
        total_label_train_val[i, :, 0] = adjust_daily_returns(total_label_train_val[i, :, 0], total_label_train_val[i, :, 4])
        total_group_train_val[i, :, :] = np.array(grouped_liquidity.loc[date])[:pid_num].reshape(-1, 1)  # 流动性
    
    # 类似地，date_list_test 被定义为测试集的日期范围，时间从 dt4 到 dt5。
    date_list_test = total_date_list[np.where((total_date_list >= dt4) & (total_date_list < dt5))[0]]
    total_ts_test1 = np.zeros((len(date_list_test), pid_num, factor_num))
    total_label_test = np.zeros((len(date_list_test), pid_num, 5))
    total_group_test = np.zeros((len(date_list_test), pid_num, 1))
    for i in trange(len(date_list_test), desc='test_data'):
        date = date_list_test[i]
        total_ts_test1[i, :, :] = grouped.loc[date].iloc[:pid_num, :]
        total_label_test[i, :, :] = grouped_label.loc[date].iloc[:pid_num, :]
        total_label_test[i, :, 0] = adjust_daily_returns(total_label_test[i, :, 0], total_label_test[i, :, 4])
        total_group_test[i, :, :] = np.array(grouped_liquidity.loc[date])[:pid_num].reshape(-1, 1)
    
    # 流动性数据归一化
    def min_max_standard(column):
        return (column - column.min()) / (column.max() - column.min())
    print('Min-max scaling.')
    total_group_train_val, total_group_test = min_max_standard(total_group_train_val), min_max_standard(total_group_test)
    
    # 因子数据标准化
    print('Standard scaling.')
    scaler = StandardScaler()
    total_ts_train_val1 = np.apply_along_axis(
        lambda x: np.clip(x, np.percentile(x, 0.5), np.percentile(x, 99.5)), axis=0, arr=total_ts_train_val1.reshape(-1, factor_num)
        )  # 去极值，保留0.5%-99.5%数据
    total_ts_train_val1 = total_ts_train_val1.reshape(len(date_list_train), pid_num, factor_num)
    total_ts_train_val1 = np.nan_to_num(scaler.fit_transform(total_ts_train_val1.reshape(-1, factor_num)).reshape(len(date_list_train), pid_num, factor_num), nan=0)
    total_ts_test1 = np.apply_along_axis(
        lambda x: np.clip(x, np.percentile(x, 0.5), np.percentile(x, 99.5)), axis=0, arr=total_ts_test1.reshape(-1, factor_num)
        )
    total_ts_test1 = total_ts_test1.reshape(len(date_list_test), pid_num, factor_num)
    total_ts_test1 = np.nan_to_num(scaler.transform(total_ts_test1.reshape(-1, factor_num)).reshape(len(date_list_test), pid_num, factor_num), nan=0)
    
    # KFold 交叉验证（并行训练）
    print('KFold training.')
    kf = KFold(n_splits=total_train_num, shuffle=False)
    processes = []
    for train_num, index_tuple in enumerate(kf.split(total_ts_train_val1)):
        p = mp.Process(
            target=train_one_Fold, 
            args=(
                round_num, train_num, index_tuple, main_folder_name,
                total_ts_train_val1, total_label_train_val, total_group_train_val, date_list_train,
                total_ts_test1, total_label_test, total_group_test, date_list_test,
                correlation_df, seed_list, dt1, dt2, dt3, dt4, dt5,
                factor_num, corr_thres, save_path, model_mode, multi_model
                )
            )
        processes.append(p)
        p.start()
    for p in processes:
        p.join()
    
    torch.cuda.empty_cache()
    gc.collect()
    
    # 保存测试数据
    print('Save test data.')
    total_test_output = []
    for train_num in range(total_train_num):
        test_name = 'test_output_ic' + str(round_num) + str(train_num) + '.pt'
        test_path = os.path.join(save_path, test_name)
        total_test_output.append(torch.load(test_path))
        
    total_test_path = os.path.join(save_path, total_test_name)
    total_date_pid_path = os.path.join(save_path, total_date_pid_name)
    
    total_test_output = torch.stack(total_test_output)
    weight_tensor = torch.tensor([0.1, 0.15, 0.2, 0.25, 0.3]).view(-1, *([1] * (total_test_output.dim() - 1)))
    total_test_output = (total_test_output * weight_tensor).sum(dim=0)
    torch.save(total_test_output, total_test_path)
    
    stocks = np.array(grouped_label.loc[20200102].index)
    repeated_stocks = np.tile(stocks, len(date_list_test))
    repeated_dates = np.repeat(date_list_test, len(stocks))
    date_pid_test = np.column_stack((repeated_dates, repeated_stocks))
    torch.save(date_pid_test, total_date_pid_path)
    
    del total_ts_train_val1
    del total_ts_test1
    del total_label_train_val
    del total_label_test
    del total_group_train_val
    del total_group_test
    
    torch.cuda.empty_cache()
    gc.collect()

# %% [markdown]
# # 训练和测试
#
# ```c
# Round 1. Train: 2020/07/01 2022/07/01 Validation: 2022/07/01 2022/12/30 Test: 2023/01/01 2023/07/01
# Round 2. Train: 2021/01/01 2023/01/01 Validation: 2023/01/01 2023/03/31 Test: 2023/04/01 2023/07/01
# Round 3. Train: 2021/04/01 2023/04/01 Validation: 2023/04/01 2023/06/30 Test: 2023/07/01 2023/10/01
# Round 4. Train: 2021/07/01 2023/07/01 Validation: 2023/07/01 2023/09/28 Test: 2023/10/01 2024/01/01
# Round 5. Train: 2021/10/01 2023/10/01 Validation: 2023/10/01 2023/12/29 Test: 2024/01/01 2024/04/01
# Round 6. Train: 2022/01/01 2024/01/01 Validation: 2024/01/01 2024/03/29 Test: 2024/04/01 2024/07/01
# Round 7. Train: 2022/04/01 2024/04/01 Validation: 2024/04/01 2024/06/28 Test: 2024/07/01 2024/10/01
# Round 8. Train: 2022/07/01 2024/07/01 Validation: 2024/07/01 2024/09/30 Test: 2024/10/01 2025/01/01
# Round 9. Train: 2022/10/01 2024/10/01 Validation: 2024/10/01 2024/12/31 Test: 2025/01/01 2025/02/21
# ```

# %%
folder_path = "/home/datamake134/data/haris/DL/" + main_folder_name
os.makedirs(folder_path, exist_ok=True)

# 第1轮
print('Round 1.')
round_num = 1
dt1 = int(pd.to_datetime("2020-07-01").strftime('%Y%m%d'))  # 训练集开始时间
dt2 = int(pd.to_datetime("2022-07-01").strftime('%Y%m%d'))  # 验证集开始时间
dt3 = int(pd.to_datetime("2022-12-30").strftime('%Y%m%d'))  # 验证集结束时间
dt4 = int(pd.to_datetime("2023-01-01").strftime('%Y%m%d'))  # 测试集开始时间
dt5 = int(pd.to_datetime("2023-04-01").strftime('%Y%m%d'))  # 测试集结束时间
main(
    round_num, dt1, dt2, dt3, dt4, dt5,
    correlation_df, grouped, grouped_label, grouped_liquidity,
    total_date_list, main_folder_name, corr_thres=0.9
    )
torch.cuda.empty_cache()
gc.collect()

test_output1 = torch.load("/home/datamake134/data/haris/DL/" + main_folder_name + "/test_output_1.pt")
test_output = torch.cat([test_output1])
test_output = test_output.cpu()
date_pid1 = torch.load("/home/datamake134/data/haris/DL/" + main_folder_name + "/test_date_pid_1.pt", weights_only=False)
total_date_pid = np.concatenate([date_pid1], axis=0)
total_date_pid_test = total_date_pid
grading_factor = pd.DataFrame(index=np.unique(total_date_pid_test[:, 0]), columns=np.unique(total_date_pid_test[:, 1]))
test_output_list = test_output.tolist()
for i in range(len(total_date_pid_test)):
    grading_factor.loc[total_date_pid_test[i][0], total_date_pid_test[i][1]] = test_output_list[i]
grading_factor.to_pickle("/home/datamake134/data/haris/DL/" + main_folder_name + "/单次_KFold_2023.pkl")
gc.collect()
# Out:
# Round 1.
# train_val_data:   0%|          | 0/610 [00:00<?, ?it/s]
# test_data:   0%|          | 0/59 [00:00<?, ?it/s]
# Min-max scaling.
# Standard scaling.
# /home/datamake134/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /home/datamake134/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:1137: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /home/datamake134/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:1142: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /home/datamake134/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:1162: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# /home/datamake134/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# KFold training.
# 2025/06/03 08:05:20 train.py INFO Period1, Train0, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230401
# 2025/06/03 08:05:20 train.py INFO Train1 Shape: torch.Size([488, 5255, 2790]), Val1 Shape: torch.Size([121, 5255, 2790]), Test1 Shape: torch.Size([59, 5255, 2790])
# 2025/06/03 08:05:20 train.py INFO Start Training
# 2025/06/03 08:08:20 train.py INFO Epoch[1/200], Time:180.29sec, Train Loss: 0.891918, Val Loss: 0.8682382106781006,0.8753860592842102,0.8626154065132141,0.8641434907913208,0.8679383397102356,0.8623106479644775
# 2025/06/03 08:08:20 model.py INFO Validation loss decreased (inf --> 0.868238).  Saving model 0.0...
# 2025/06/03 08:08:20 model.py INFO Validation loss decreased (inf --> 0.875386).  Saving model 1.0...
# 2025/06/03 08:08:20 model.py INFO Validation loss decreased (inf --> 0.862615).  Saving model 2.0...
# 2025/06/03 08:08:20 model.py INFO Validation loss decreased (inf --> 0.864143).  Saving model 3.0...
# 2025/06/03 08:08:20 model.py INFO Validation loss decreased (inf --> 0.867938).  Saving model 4.0...
# 2025/06/03 08:08:21 model.py INFO Validation loss decreased (inf --> 0.862311).  Saving model 5.0...
# 2025/06/03 08:09:35 train.py INFO Period1, Train1, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230401
# 2025/06/03 08:09:35 train.py INFO Train1 Shape: torch.Size([488, 5255, 2790]), Val1 Shape: torch.Size([121, 5255, 2790]), Test1 Shape: torch.Size([59, 5255, 2790])
# 2025/06/03 08:09:35 train.py INFO Start Training
# 2025/06/03 08:11:24 train.py INFO Epoch[2/200], Time:183.43sec, Train Loss: 0.859579, Val Loss: 0.8596321940422058,0.8639485836029053,0.8506546020507812,0.8542912602424622,0.8623238205909729,0.8522453904151917
# 2025/06/03 08:11:24 model.py INFO Validation loss decreased (0.868238 --> 0.859632).  Saving model 0.0...
# 2025/06/03 08:11:24 model.py INFO Validation loss decreased (0.875386 --> 0.863949).  Saving model 1.0...
# 2025/06/03 08:11:24 model.py INFO Validation loss decreased (0.862615 --> 0.850655).  Saving model 2.0...
# 2025/06/03 08:11:25 model.py INFO Validation loss decreased (0.864143 --> 0.854291).  Saving model 3.0...
# 2025/06/03 08:11:25 model.py INFO Validation loss decreased (0.867938 --> 0.862324).  Saving model 4.0...
# 2025/06/03 08:11:25 model.py INFO Validation loss decreased (0.862311 --> 0.852245).  Saving model 5.0...
# 2025/06/03 08:12:11 train.py INFO Epoch[1/200], Time:155.91sec, Train Loss: 0.890598, Val Loss: 0.8707793951034546,0.8667831420898438,0.8663456439971924,0.8758310675621033,0.8664501309394836,0.8661768436431885
# 2025/06/03 08:12:11 model.py INFO Validation loss decreased (inf --> 0.870779).  Saving model 0.0...
# 2025/06/03 08:12:11 model.py INFO Validation loss decreased (inf --> 0.866783).  Saving model 1.0...
# 2025/06/03 08:12:11 model.py INFO Validation loss decreased (inf --> 0.866346).  Saving model 2.0...
# 2025/06/03 08:12:11 model.py INFO Validation loss decreased (inf --> 0.875831).  Saving model 3.0...
# 2025/06/03 08:12:11 model.py INFO Validation loss decreased (inf --> 0.866450).  Saving model 4.0...
# 2025/06/03 08:12:11 model.py INFO Validation loss decreased (inf --> 0.866177).  Saving model 5.0...
# 2025/06/03 08:14:33 train.py INFO Epoch[3/200], Time:187.91sec, Train Loss: 0.845928, Val Loss: 0.8546775579452515,0.859801173210144,0.8480061292648315,0.8504154086112976,0.8550353646278381,0.8457441329956055
# 2025/06/03 08:14:33 model.py INFO Validation loss decreased (0.859632 --> 0.854678).  Saving model 0.0...
# 2025/06/03 08:14:33 model.py INFO Validation loss decreased (0.863949 --> 0.859801).  Saving model 1.0...
# 2025/06/03 08:14:33 model.py INFO Validation loss decreased (0.850655 --> 0.848006).  Saving model 2.0...
# 2025/06/03 08:14:33 model.py INFO Validation loss decreased (0.854291 --> 0.850415).  Saving model 3.0...
# 2025/06/03 08:14:33 model.py INFO Validation loss decreased (0.862324 --> 0.855035).  Saving model 4.0...
# 2025/06/03 08:14:33 model.py INFO Validation loss decreased (0.852245 --> 0.845744).  Saving model 5.0...
# 2025/06/03 08:14:43 train.py INFO Period1, Train2, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230401
# 2025/06/03 08:14:43 train.py INFO Train1 Shape: torch.Size([488, 5255, 2790]), Val1 Shape: torch.Size([121, 5255, 2790]), Test1 Shape: torch.Size([59, 5255, 2790])
# 2025/06/03 08:14:43 train.py INFO Start Training
# 2025/06/03 08:15:00 train.py INFO Epoch[2/200], Time:168.47sec, Train Loss: 0.857243, Val Loss: 0.8702515959739685,0.8563098311424255,0.8551529049873352,0.8735156655311584,0.8531951308250427,0.8558084964752197
# 2025/06/03 08:15:00 model.py INFO Validation loss decreased (0.870779 --> 0.870252).  Saving model 0.0...
# 2025/06/03 08:15:00 model.py INFO Validation loss decreased (0.866783 --> 0.856310).  Saving model 1.0...
# 2025/06/03 08:15:00 model.py INFO Validation loss decreased (0.866346 --> 0.855153).  Saving model 2.0...
# 2025/06/03 08:15:00 model.py INFO Validation loss decreased (0.875831 --> 0.873516).  Saving model 3.0...
# 2025/06/03 08:15:01 model.py INFO Validation loss decreased (0.866450 --> 0.853195).  Saving model 4.0...
# 2025/06/03 08:15:01 model.py INFO Validation loss decreased (0.866177 --> 0.855808).  Saving model 5.0...
# 2025/06/03 08:17:34 train.py INFO Epoch[1/200], Time:171.27sec, Train Loss: 0.885551, Val Loss: 0.8914868235588074,0.8913922309875488,0.893738329410553,0.8881435990333557,0.8897920250892639,0.8933566212654114
# 2025/06/03 08:17:34 model.py INFO Validation loss decreased (inf --> 0.891487).  Saving model 0.0...
# 2025/06/03 08:17:35 model.py INFO Validation loss decreased (inf --> 0.891392).  Saving model 1.0...
# 2025/06/03 08:17:35 model.py INFO Validation loss decreased (inf --> 0.893738).  Saving model 2.0...
# 2025/06/03 08:17:35 model.py INFO Validation loss decreased (inf --> 0.888144).  Saving model 3.0...
# 2025/06/03 08:17:35 model.py INFO Validation loss decreased (inf --> 0.889792).  Saving model 4.0...
# 2025/06/03 08:17:35 model.py INFO Validation loss decreased (inf --> 0.893357).  Saving model 5.0...
# 2025/06/03 08:17:44 train.py INFO Epoch[4/200], Time:190.82sec, Train Loss: 0.835467, Val Loss: 0.8529391884803772,0.8575257062911987,0.8460381627082825,0.8508322238922119,0.8535428643226624,0.8446598052978516
# 2025/06/03 08:17:44 model.py INFO Validation loss decreased (0.854678 --> 0.852939).  Saving model 0.0...
# 2025/06/03 08:17:45 model.py INFO Validation loss decreased (0.859801 --> 0.857526).  Saving model 1.0...
# 2025/06/03 08:17:45 model.py INFO Validation loss decreased (0.848006 --> 0.846038).  Saving model 2.0...
# 2025/06/03 08:17:45 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:17:45 model.py INFO Validation loss decreased (0.855035 --> 0.853543).  Saving model 4.0...
# 2025/06/03 08:17:45 model.py INFO Validation loss decreased (0.845744 --> 0.844660).  Saving model 5.0...
# 2025/06/03 08:17:54 train.py INFO Epoch[3/200], Time:172.70sec, Train Loss: 0.843353, Val Loss: 0.8708373308181763,0.850415825843811,0.8491613864898682,0.8701910972595215,0.8507621884346008,0.8523629307746887
# 2025/06/03 08:17:54 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:17:54 model.py INFO Validation loss decreased (0.856310 --> 0.850416).  Saving model 1.0...
# 2025/06/03 08:17:54 model.py INFO Validation loss decreased (0.855153 --> 0.849161).  Saving model 2.0...
# 2025/06/03 08:17:54 model.py INFO Validation loss decreased (0.873516 --> 0.870191).  Saving model 3.0...
# 2025/06/03 08:17:54 model.py INFO Validation loss decreased (0.853195 --> 0.850762).  Saving model 4.0...
# 2025/06/03 08:17:54 model.py INFO Validation loss decreased (0.855808 --> 0.852363).  Saving model 5.0...
# 2025/06/03 08:20:30 train.py INFO Period1, Train3, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230401
# 2025/06/03 08:20:30 train.py INFO Train1 Shape: torch.Size([488, 5255, 2790]), Val1 Shape: torch.Size([121, 5255, 2790]), Test1 Shape: torch.Size([59, 5255, 2790])
# 2025/06/03 08:20:30 train.py INFO Start Training
# 2025/06/03 08:20:36 train.py INFO Epoch[2/200], Time:181.04sec, Train Loss: 0.851596, Val Loss: 0.8769029378890991,0.8852400183677673,0.8859519958496094,0.8775720000267029,0.8825603723526001,0.8838877081871033
# 2025/06/03 08:20:36 model.py INFO Validation loss decreased (0.891487 --> 0.876903).  Saving model 0.0...
# 2025/06/03 08:20:36 model.py INFO Validation loss decreased (0.891392 --> 0.885240).  Saving model 1.0...
# 2025/06/03 08:20:37 model.py INFO Validation loss decreased (0.893738 --> 0.885952).  Saving model 2.0...
# 2025/06/03 08:20:37 model.py INFO Validation loss decreased (0.888144 --> 0.877572).  Saving model 3.0...
# 2025/06/03 08:20:37 model.py INFO Validation loss decreased (0.889792 --> 0.882560).  Saving model 4.0...
# 2025/06/03 08:20:37 model.py INFO Validation loss decreased (0.893357 --> 0.883888).  Saving model 5.0...
# 2025/06/03 08:20:54 train.py INFO Epoch[4/200], Time:179.44sec, Train Loss: 0.832301, Val Loss: 0.8707298636436462,0.8458009958267212,0.8522657752037048,0.8745052218437195,0.845170259475708,0.8518043160438538
# 2025/06/03 08:20:54 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 08:20:54 model.py INFO Validation loss decreased (0.850416 --> 0.845801).  Saving model 1.0...
# 2025/06/03 08:20:54 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:20:54 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:20:54 model.py INFO Validation loss decreased (0.850762 --> 0.845170).  Saving model 4.0...
# 2025/06/03 08:20:54 model.py INFO Validation loss decreased (0.852363 --> 0.851804).  Saving model 5.0...
# 2025/06/03 08:21:11 train.py INFO Epoch[5/200], Time:205.56sec, Train Loss: 0.825726, Val Loss: 0.852016270160675,0.856316328048706,0.8462410569190979,0.8555958271026611,0.8561963438987732,0.8491585850715637
# 2025/06/03 08:21:11 model.py INFO Validation loss decreased (0.852939 --> 0.852016).  Saving model 0.0...
# 2025/06/03 08:21:11 model.py INFO Validation loss decreased (0.857526 --> 0.856316).  Saving model 1.0...
# 2025/06/03 08:21:11 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:21:11 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 08:21:11 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:21:11 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:23:34 train.py INFO Epoch[1/200], Time:183.97sec, Train Loss: 0.889801, Val Loss: 0.8814353346824646,0.8712562322616577,0.8679512739181519,0.8750614523887634,0.8708910346031189,0.8681728839874268
# 2025/06/03 08:23:34 model.py INFO Validation loss decreased (inf --> 0.881435).  Saving model 0.0...
# 2025/06/03 08:23:34 model.py INFO Validation loss decreased (inf --> 0.871256).  Saving model 1.0...
# 2025/06/03 08:23:34 model.py INFO Validation loss decreased (inf --> 0.867951).  Saving model 2.0...
# 2025/06/03 08:23:34 model.py INFO Validation loss decreased (inf --> 0.875061).  Saving model 3.0...
# 2025/06/03 08:23:34 model.py INFO Validation loss decreased (inf --> 0.870891).  Saving model 4.0...
# 2025/06/03 08:23:34 model.py INFO Validation loss decreased (inf --> 0.868173).  Saving model 5.0...
# 2025/06/03 08:23:36 train.py INFO Epoch[3/200], Time:179.24sec, Train Loss: 0.837288, Val Loss: 0.8738144636154175,0.8809685707092285,0.883622407913208,0.8735871315002441,0.8781750202178955,0.8818438053131104
# 2025/06/03 08:23:36 model.py INFO Validation loss decreased (0.876903 --> 0.873814).  Saving model 0.0...
# 2025/06/03 08:23:36 model.py INFO Validation loss decreased (0.885240 --> 0.880969).  Saving model 1.0...
# 2025/06/03 08:23:37 model.py INFO Validation loss decreased (0.885952 --> 0.883622).  Saving model 2.0...
# 2025/06/03 08:23:37 model.py INFO Validation loss decreased (0.877572 --> 0.873587).  Saving model 3.0...
# 2025/06/03 08:23:37 model.py INFO Validation loss decreased (0.882560 --> 0.878175).  Saving model 4.0...
# 2025/06/03 08:23:37 model.py INFO Validation loss decreased (0.883888 --> 0.881844).  Saving model 5.0...
# 2025/06/03 08:23:52 train.py INFO Epoch[5/200], Time:177.99sec, Train Loss: 0.821939, Val Loss: 0.8668057918548584,0.8434526920318604,0.8510997295379639,0.8798699378967285,0.8417185544967651,0.8549901247024536
# 2025/06/03 08:23:52 model.py INFO Validation loss decreased (0.870252 --> 0.866806).  Saving model 0.0...
# 2025/06/03 08:23:52 model.py INFO Validation loss decreased (0.845801 --> 0.843453).  Saving model 1.0...
# 2025/06/03 08:23:52 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 08:23:52 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 08:23:52 model.py INFO Validation loss decreased (0.845170 --> 0.841719).  Saving model 4.0...
# 2025/06/03 08:23:52 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:24:25 train.py INFO Epoch[6/200], Time:193.85sec, Train Loss: 0.814921, Val Loss: 0.8530372977256775,0.8585285544395447,0.8411160111427307,0.8560014963150024,0.8590317964553833,0.8488565683364868
# 2025/06/03 08:24:25 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:24:25 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:24:25 model.py INFO Validation loss decreased (0.846038 --> 0.841116).  Saving model 2.0...
# 2025/06/03 08:24:25 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/06/03 08:24:25 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 08:24:25 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 08:26:42 train.py INFO Epoch[4/200], Time:185.19sec, Train Loss: 0.825534, Val Loss: 0.8714383244514465,0.8804865479469299,0.8816788196563721,0.8686246871948242,0.8804419636726379,0.8802143931388855
# 2025/06/03 08:26:42 model.py INFO Validation loss decreased (0.873814 --> 0.871438).  Saving model 0.0...
# 2025/06/03 08:26:42 train.py INFO Epoch[2/200], Time:187.86sec, Train Loss: 0.855977, Val Loss: 0.8733577728271484,0.860744297504425,0.8599866032600403,0.8710768818855286,0.8616299033164978,0.8599898815155029
# 2025/06/03 08:26:42 model.py INFO Validation loss decreased (0.881435 --> 0.873358).  Saving model 0.0...
# 2025/06/03 08:26:42 model.py INFO Validation loss decreased (0.880969 --> 0.880487).  Saving model 1.0...
# 2025/06/03 08:26:43 model.py INFO Validation loss decreased (0.871256 --> 0.860744).  Saving model 1.0...
# 2025/06/03 08:26:43 model.py INFO Validation loss decreased (0.883622 --> 0.881679).  Saving model 2.0...
# 2025/06/03 08:26:43 model.py INFO Validation loss decreased (0.873587 --> 0.868625).  Saving model 3.0...
# 2025/06/03 08:26:43 model.py INFO Validation loss decreased (0.867951 --> 0.859987).  Saving model 2.0...
# 2025/06/03 08:26:43 model.py INFO Validation loss decreased (0.875061 --> 0.871077).  Saving model 3.0...
# 2025/06/03 08:26:43 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:26:43 model.py INFO Validation loss decreased (0.881844 --> 0.880214).  Saving model 5.0...
# 2025/06/03 08:26:43 model.py INFO Validation loss decreased (0.870891 --> 0.861630).  Saving model 4.0...
# 2025/06/03 08:26:44 model.py INFO Validation loss decreased (0.868173 --> 0.859990).  Saving model 5.0...
# 2025/06/03 08:27:03 train.py INFO Epoch[6/200], Time:190.46sec, Train Loss: 0.810450, Val Loss: 0.8617949485778809,0.8408443927764893,0.8544901013374329,0.8786220550537109,0.8418335914611816,0.8540011048316956
# 2025/06/03 08:27:03 model.py INFO Validation loss decreased (0.866806 --> 0.861795).  Saving model 0.0...
# 2025/06/03 08:27:03 model.py INFO Validation loss decreased (0.843453 --> 0.840844).  Saving model 1.0...
# 2025/06/03 08:27:03 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/06/03 08:27:03 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/06/03 08:27:03 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:27:03 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 08:27:55 train.py INFO Epoch[7/200], Time:210.41sec, Train Loss: 0.802733, Val Loss: 0.8582543730735779,0.8566857576370239,0.846941351890564,0.8612794280052185,0.8606672286987305,0.8530372381210327
# 2025/06/03 08:27:55 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 08:27:55 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 08:27:55 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:27:55 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/06/03 08:27:55 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/06/03 08:27:55 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/06/03 08:30:10 train.py INFO Epoch[5/200], Time:206.13sec, Train Loss: 0.814071, Val Loss: 0.8692117929458618,0.8759404420852661,0.8834084272384644,0.8655455112457275,0.8783215284347534,0.8729782104492188
# 2025/06/03 08:30:10 model.py INFO Validation loss decreased (0.871438 --> 0.869212).  Saving model 0.0...
# 2025/06/03 08:30:10 model.py INFO Validation loss decreased (0.880487 --> 0.875940).  Saving model 1.0...
# 2025/06/03 08:30:10 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:30:10 model.py INFO Validation loss decreased (0.868625 --> 0.865546).  Saving model 3.0...
# 2025/06/03 08:30:10 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 08:30:10 model.py INFO Validation loss decreased (0.880214 --> 0.872978).  Saving model 5.0...
# 2025/06/03 08:30:15 train.py INFO Epoch[3/200], Time:211.35sec, Train Loss: 0.841565, Val Loss: 0.8747432231903076,0.8582093715667725,0.856200098991394,0.8689638376235962,0.8562799096107483,0.8531553745269775
# 2025/06/03 08:30:15 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:30:15 model.py INFO Validation loss decreased (0.860744 --> 0.858209).  Saving model 1.0...
# 2025/06/03 08:30:15 model.py INFO Validation loss decreased (0.859987 --> 0.856200).  Saving model 2.0...
# 2025/06/03 08:30:15 model.py INFO Validation loss decreased (0.871077 --> 0.868964).  Saving model 3.0...
# 2025/06/03 08:30:15 model.py INFO Validation loss decreased (0.861630 --> 0.856280).  Saving model 4.0...
# 2025/06/03 08:30:16 model.py INFO Validation loss decreased (0.859990 --> 0.853155).  Saving model 5.0...
# 2025/06/03 08:30:30 train.py INFO Epoch[7/200], Time:206.57sec, Train Loss: 0.796850, Val Loss: 0.862401008605957,0.8436557054519653,0.8556159734725952,0.8771750330924988,0.8406925201416016,0.8575881719589233
# 2025/06/03 08:30:30 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:30:30 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:30:30 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/06/03 08:30:30 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/06/03 08:30:30 model.py INFO Validation loss decreased (0.841719 --> 0.840693).  Saving model 4.0...
# 2025/06/03 08:30:30 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/06/03 08:31:25 train.py INFO Period1, Train4, Train Period:20200701-20220701, Val Period:20220701-20221230, Test Period:20230101-20230401
# 2025/06/03 08:31:25 train.py INFO Train1 Shape: torch.Size([488, 5255, 2790]), Val1 Shape: torch.Size([121, 5255, 2790]), Test1 Shape: torch.Size([59, 5255, 2790])
# 2025/06/03 08:31:25 train.py INFO Start Training
# 2025/06/03 08:31:36 train.py INFO Epoch[8/200], Time:220.86sec, Train Loss: 0.787548, Val Loss: 0.8561210632324219,0.8573631644248962,0.8487915992736816,0.862930178642273,0.8643761873245239,0.85109543800354
# 2025/06/03 08:31:36 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/06/03 08:31:36 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/06/03 08:31:36 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 08:31:36 model.py INFO EarlyStopping counter: 5 out of 10
# 2025/06/03 08:31:36 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/06/03 08:31:36 model.py INFO EarlyStopping counter: 4 out of 10
# 2025/06/03 08:33:24 train.py INFO Epoch[6/200], Time:193.58sec, Train Loss: 0.801877, Val Loss: 0.8715270757675171,0.8771387934684753,0.8851085305213928,0.8664240837097168,0.8817685842514038,0.8751795887947083
# 2025/06/03 08:33:24 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:33:24 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:33:24 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 08:33:24 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:33:24 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/06/03 08:33:24 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:33:36 train.py INFO Epoch[4/200], Time:200.25sec, Train Loss: 0.829994, Val Loss: 0.8717519044876099,0.8513895273208618,0.8545836210250854,0.87254798412323,0.8523287177085876,0.849027156829834
# 2025/06/03 08:33:36 model.py INFO Validation loss decreased (0.873358 --> 0.871752).  Saving model 0.0...
# 2025/06/03 08:33:36 model.py INFO Validation loss decreased (0.858209 --> 0.851390).  Saving model 1.0...
# 2025/06/03 08:33:36 model.py INFO Validation loss decreased (0.856200 --> 0.854584).  Saving model 2.0...
# 2025/06/03 08:33:37 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 08:33:37 model.py INFO Validation loss decreased (0.856280 --> 0.852329).  Saving model 4.0...
# 2025/06/03 08:33:37 model.py INFO Validation loss decreased (0.853155 --> 0.849027).  Saving model 5.0...
# 2025/06/03 08:33:44 train.py INFO Epoch[8/200], Time:194.43sec, Train Loss: 0.780421, Val Loss: 0.8655487298965454,0.8490668535232544,0.8732025027275085,0.8765386343002319,0.8444708585739136,0.8601105213165283
# 2025/06/03 08:33:44 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 08
train.py INFO Train1 Shape: torch.Size([434, 5255, 2790]), Val1 Shape: torch.Size([108, 5255, 2790]), Test1 Shape: torch.Size([59, 5255, 2790])
# 2025/06/03 09:28:16 train.py INFO Start Training
# 2025/06/03 09:31:00 train.py INFO Epoch[1/200], Time:163.99sec, Train Loss: 0.898508, Val Loss: 0.8658998012542725,0.8675944805145264,0.865696132183075,0.8699872493743896,0.8688603043556213,0.8676736354827881
# 2025/06/03 09:31:00 model.py INFO Validation loss decreased (inf --> 0.865900).  Saving model 0.0...
# 2025/06/03 09:31:00 model.py INFO Validation loss decreased (inf --> 0.867594).  Saving model 1.0...
# 2025/06/03 09:31:00 model.py INFO Validation loss decreased (inf --> 0.865696).  Saving model 2.0...
# 2025/06/03 09:31:00 model.py INFO Validation loss decreased (inf --> 0.869987).  Saving model 3.0...
# 2025/06/03 09:31:00 model.py INFO Validation loss decreased (inf --> 0.868860).  Saving model 4.0...
# 2025/06/03 09:31:01 model.py INFO Validation loss decreased (inf --> 0.867674).  Saving model 5.0...
# 2025/06/03 09:33:36 train.py INFO Epoch[2/200], Time:155.71sec, Train Loss: 0.865788, Val Loss: 0.857179582118988,0.8524451851844788,0.8529191613197327,0.8586488366127014,0.8540514707565308,0.8535527586936951
# 2025/06/03 09:33:36 model.py INFO Validation loss decreased (0.865900 --> 0.857180).  Saving model 0.0...
# 2025/06/03 09:33:37 model.py INFO Validation loss decreased (0.867594 --> 0.852445).  Saving model 1.0...
# 2025/06/03 09:33:37 model.py INFO Validation loss decreased (0.865696 --> 0.852919).  Saving model 2.0...
# 2025/06/03 09:33:37 model.py INFO Validation loss decreased (0.869987 --> 0.858649).  Saving model 3.0...
# 2025/06/03 09:33:37 model.py INFO Validation loss decreased (0.868860 --> 0.854051).  Saving model 4.0...
# 2025/06/03 09:33:37 model.py INFO Validation loss decreased (0.867674 --> 0.853553).  Saving model 5.0...
# 2025/06/03 09:34:40 train.py INFO Period2, Train1, Train Period:20210101-20230101, Val Period:20230101-20230331, Test Period:20230401-20230701
# 2025/06/03 09:34:40 train.py INFO Train1 Shape: torch.Size([434, 5255, 2790]), Val1 Shape: torch.Size([108, 5255, 2790]), Test1 Shape: torch.Size([59, 5255, 2790])
# 2025/06/03 09:34:40 train.py INFO Start Training
# 2025/06/03 09:36:25 train.py INFO Epoch[3/200], Time:167.89sec, Train Loss: 0.851977, Val Loss: 0.8547838926315308,0.8473471403121948,0.8479623794555664,0.8546797633171082,0.8487286567687988,0.8524779081344604
# 2025/06/03 09:36:25 model.py INFO Validation loss decreased (0.857180 --> 0.854784).  Saving model 0.0...
# 2025/06/03 09:36:25 model.py INFO Validation loss decreased (0.852445 --> 0.847347).  Saving model 1.0...
# 2025/06/03 09:36:25 model.py INFO Validation loss decreased (0.852919 --> 0.847962).  Saving model 2.0...
# 2025/06/03 09:36:26 model.py INFO Validation loss decreased (0.858649 --> 0.854680).  Saving model 3.0...
# 2025/06/03 09:36:26 model.py INFO Validation loss decreased (0.854051 --> 0.848729).  Saving model 4.0...
# 2025/06/03 09:36:26 model.py INFO Validation loss decreased (0.853553 --> 0.852478).  Saving model 5.0...
# 2025/06/03 09:36:39 train.py INFO Period2, Train2, Train Period:20210101-20230101, Val Period:20230101-20230331, Test Period:20230401-20230701
# 2025/06/03 09:36:39 train.py INFO Train1 Shape: torch.Size([434, 5255, 2790]), Val1 Shape: torch.Size([108, 5255, 2790]), Test1 Shape: torch.Size([59, 5255, 2790])
# 2025/06/03 09:36:39 train.py INFO Start Training
# 2025/06/03 09:37:24 train.py INFO Epoch[1/200], Time:164.38sec, Train Loss: 0.894095, Val Loss: 0.8907082080841064,0.8886298537254333,0.8845850229263306,0.8928807377815247,0.8934992551803589,0.8851549029350281
# 2025/06/03 09:37:24 model.py INFO Validation loss decreased (inf --> 0.890708).  Saving model 0.0...
# 2025/06/03 09:37:25 model.py INFO Validation loss decreased (inf --> 0.888630).  Saving model 1.0...
# 2025/06/03 09:37:25 model.py INFO Validation loss decreased (inf --> 0.884585).  Saving model 2.0...
# 2025/06/03 09:37:25 model.py INFO Validation loss decreased (inf --> 0.892881).  Saving model 3.0...
# 2025/06/03 09:37:25 model.py INFO Validation loss decreased (inf --> 0.893499).  Saving model 4.0...
# 2025/06/03 09:37:25 model.py INFO Validation loss decreased (inf --> 0.885155).  Saving model 5.0...
# 2025/06/03 09:39:09 train.py INFO Epoch[4/200], Time:163.31sec, Train Loss: 0.841436, Val Loss: 0.8547288179397583,0.8474635481834412,0.8468924164772034,0.8531043529510498,0.8482528924942017,0.8468641638755798
# 2025/06/03 09:39:09 model.py INFO Validation loss decreased (0.854784 --> 0.854729).  Saving model 0.0...
# 2025/06/03 09:39:10 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 09:39:10 model.py INFO Validation loss decreased (0.847962 --> 0.846892).  Saving model 2.0...
# 2025/06/03 09:39:10 model.py INFO Validation loss decreased (0.854680 --> 0.853104).  Saving model 3.0...
# 2025/06/03 09:39:10 model.py INFO Validation loss decreased (0.848729 --> 0.848253).  Saving model 4.0...
# 2025/06/03 09:39:10 model.py INFO Validation loss decreased (0.852478 --> 0.846864).  Saving model 5.0...
# 2025/06/03 09:39:13 train.py INFO Epoch[1/200], Time:154.23sec, Train Loss: 0.898338, Val Loss: 0.8779874444007874,0.8705046772956848,0.8725236058235168,0.8767336010932922,0.875158429145813,0.8763087391853333
# 2025/06/03 09:39:13 model.py INFO Validation loss decreased (inf --> 0.877987).  Saving model 0.0...
# 2025/06/03 09:39:13 model.py INFO Validation loss decreased (inf --> 0.870505).  Saving model 1.0...
# 2025/06/03 09:39:14 model.py INFO Validation loss decreased (inf --> 0.872524).  Saving model 2.0...
# 2025/06/03 09:39:14 model.py INFO Validation loss decreased (inf --> 0.876734).  Saving model 3.0...
# 2025/06/03 09:39:14 model.py INFO Validation loss decreased (inf --> 0.875158).  Saving model 4.0...
# 2025/06/03 09:39:14 model.py INFO Validation loss decreased (inf --> 0.876309).  Saving model 5.0...
# 2025/06/03 09:40:00 train.py INFO Epoch[2/200], Time:154.44sec, Train Loss: 0.862831, Val Loss: 0.8828461170196533,0.8791547417640686,0.8708463311195374,0.884929358959198,0.8828104138374329,0.8707004189491272
# 2025/06/03 09:40:00 model.py INFO Validation loss decreased (0.890708 --> 0.882846).  Saving model 0.0...
# 2025/06/03 09:40:00 model.py INFO Validation loss decreased (0.888630 --> 0.879155).  Saving model 1.0...
# 2025/06/03 09:40:00 model.py INFO Validation loss decreased (0.884585 --> 0.870846).  Saving model 2.0...
# 2025/06/03 09:40:00 model.py INFO Validation loss decreased (0.892881 --> 0.884929).  Saving model 3.0...
# 2025/06/03 09:40:00 model.py INFO Validation loss decreased (0.893499 --> 0.882810).  Saving model 4.0...
# 2025/06/03 09:40:00 model.py INFO Validation loss decreased (0.885155 --> 0.870700).  Saving model 5.0...
# 2025/06/03 09:41:42 train.py INFO Epoch[2/200], Time:147.65sec, Train Loss: 0.865773, Val Loss: 0.873085618019104,0.865399956703186,0.864368200302124,0.873954176902771,0.864290714263916,0.862106442451477
# 2025/06/03 09:41:42 model.py INFO Validation loss decreased (0.877987 --> 0.873086).  Saving model 0.0...
# 2025/06/03 09:41:42 model.py INFO Validation loss decreased (0.870505 --> 0.865400).  Saving model 1.0...
# 2025/06/03 09:41:42 model.py INFO Validation loss decreased (0.872524 --> 0.864368).  Saving model 2.0...
# 2025/06/03 09:41:42 model.py INFO Validation loss decreased (0.876734 --> 0.873954).  Saving model 3.0...
# 2025/06/03 09:41:42 model.py INFO Validation loss decreased (0.875158 --> 0.864291).  Saving model 4.0...
# 2025/06/03 09:41:42 model.py INFO Validation loss decreased (0.876309 --> 0.862106).  Saving model 5.0...
# 2025/06/03 09:41:49 train.py INFO Epoch[5/200], Time:159.19sec, Train Loss: 0.831273, Val Loss: 0.8575649261474609,0.8502967357635498,0.844772219657898,0.8550933599472046,0.8535452485084534,0.8457345366477966
# 2025/06/03 09:41:49 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 09:41:49 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 09:41:49 model.py INFO Validation loss decreased (0.846892 --> 0.844772).  Saving model 2.0...
# 2025/06/03 09:41:49 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 09:41:49 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 09:41:49 model.py INFO Validation loss decreased (0.846864 --> 0.845735).  Saving model 5.0...
# 2025/06/03 09:42:36 train.py INFO Epoch[3/200], Time:155.36sec, Train Loss: 0.849545, Val Loss: 0.8833836913108826,0.8747645616531372,0.865822434425354,0.8849918246269226,0.8755017518997192,0.8646351099014282
# 2025/06/03 09:42:36 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 09:42:36 model.py INFO Validation loss decreased (0.879155 --> 0.874765).  Saving model 1.0...
# 2025/06/03 09:42:36 model.py INFO Validation loss decreased (0.870846 --> 0.865822).  Saving model 2.0...
# 2025/06/03 09:42:36 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 09:42:36 model.py INFO Validation loss decreased (0.882810 --> 0.875502).  Saving model 4.0...
# 2025/06/03 09:42:36 model.py INFO Validation loss decreased (0.870700 --> 0.864635).  Saving model 5.0...
# 2025/06/03 09:44:10 train.py INFO Epoch[3/200], Time:147.16sec, Train Loss: 0.851132, Val Loss: 0.8727160692214966,0.8594783544540405,0.8598653078079224,0.871859073638916,0.8623985052108765,0.8585686683654785
# 2025/06/03 09:44:10 model.py INFO Validation loss decreased (0.873086 --> 0.872716).  Saving model 0.0...
# 2025/06/03 09:44:10 model.py INFO Validation loss decreased (0.865400 --> 0.859478).  Saving model 1.0...
# 2025/06/03 09:44:10 model.py INFO Validation loss decreased (0.864368 --> 0.859865).  Saving model 2.0...
# 2025/06/03 09:44:10 model.py INFO Validation loss decreased (0.873954 --> 0.871859).  Saving model 3.0...
# 2025/06/03 09:44:10 model.py INFO Validation loss decreased (0.864291 --> 0.862399).  Saving model 4.0...
# 2025/06/03 09:44:10 model.py INFO Validation loss decreased (0.862106 --> 0.858569).  Saving model 5.0...
# 2025/06/03 09:44:33 train.py INFO Epoch[6/200], Time:163.83sec, Train Loss: 0.820707, Val Loss: 0.8619883060455322,0.8529109954833984,0.8450055122375488,0.8627119660377502,0.8513614535331726,0.8464757204055786
# 2025/06/03 09:44:33 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 09:44:33 model.py INFO EarlyStopping counter: 3 out of 10
# 2025/06/03 09:44:33 model.py INFO EarlyStopping counter: 1 out of 10
# 2025/06/03 09:44:33 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 09:44:33 model.py INFO EarlyStopping counter: 2 out of 10
# 2025/06/03 09:44:33 model.py INFO EarlyStopping counter: 1 out of 10
